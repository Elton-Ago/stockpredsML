# %%
import pandas as pd
import datetime
import yfinance as yf
import matplotlib.pyplot as plt
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
start_date = '2016-01-01'
end_date = '2023-01-01'

symbol = 'AAPL'
apple_data_df = yf.download(symbol, start_date, end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
apple_data_df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2016-01-04   25.652500   26.342501   25.500000   26.337500   24.041487
# 2016-01-05   26.437500   26.462500   25.602501   25.677500   23.439018
# 2016-01-06   25.139999   25.592501   24.967501   25.174999   22.980326
# 2016-01-07   24.670000   25.032499   24.107500   24.112499   22.010450
# 2016-01-08   24.637501   24.777500   24.190001   24.240000   22.126835
# ...                ...         ...         ...         ...         ...
# 2022-12-23  130.919998  132.419998  129.639999  131.860001  131.477127
# 2022-12-27  131.380005  131.410004  128.720001  130.029999  129.652435
# 2022-12-28  129.669998  131.029999  125.870003  126.040001  125.674026
# 2022-12-29  127.989998  130.479996  127.730003  129.610001  129.233658
# 2022-12-30  128.410004  129.949997  127.430000  129.929993  129.552719
#
#                Volume
# Date
# 2016-01-04  270597600
# 2016-01-05  223164000
# 2016-01-06  273829600
# ...

# %%
apple_data_df['Adj Close'].plot(figsize=(10,7))
plt.title("Apple Data (2020-2023)", fontsize=14)
plt.ylabel("Price ($)", fontsize=12)
plt.xlabel("Month ", fontsize=12)
plt.grid(which='major', color='b', linestyle='-.', linewidth=0.5)
plt.show()

# %%
start_date = '2013-01-01'
end_date = '2023-01-01'

symbols_list = ['AAPL','META','NVDA','TSLA','GOOGL','AMZN','IBM','KO','MSFT']

data_set = pd.DataFrame(columns=symbols_list)

for symbol in symbols_list:
    data_set[symbol] = yf.download(symbol, start_date, end_date)['Adj Close']
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# [*********************100%***********************]  1 of 1 completed

# %%
data_set
# Out:
#                   AAPL        META        NVDA        TSLA      GOOGL  \
# Date
# 2013-01-02   16.813858   28.000000    2.936478    2.357333  18.099348
# 2013-01-03   16.601629   27.770000    2.938786    2.318000  18.109859
# 2013-01-04   16.139202   28.760000    3.035746    2.293333  18.467718
# 2013-01-07   16.044262   29.420000    2.948021    2.289333  18.387136
# 2013-01-08   16.087444   29.059999    2.883382    2.245333  18.350851
# ...                ...         ...         ...         ...        ...
# 2022-12-23  131.477127  118.040001  152.018448  123.150002  89.230003
# 2022-12-27  129.652435  116.879997  141.171417  109.099998  87.389999
# 2022-12-28  125.674019  115.620003  140.321640  112.709999  86.019997
# 2022-12-29  129.233658  120.260002  145.990097  121.820000  88.449997
# 2022-12-30  129.552719  120.339996  146.100067  123.180000  88.230003
#
#                  AMZN         IBM         KO        MSFT
# Date
# ...

# %%
data_set.plot(figsize=(10,7))
plt.legend()
plt.title("Adjusted Close Price", fontsize=16)
plt.ylabel("Price ($)", fontsize=14)
plt.xlabel("Year", fontsize=14)
plt.grid(which='major', color='k', linestyle='-.', linewidth=0.5)
plt.show()

# %%
intraday_data_AAPL = yf.download(tickers='AAPL', period='5d', interval='1m', auto_adjust=True)
intraday_data_AAPL
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                  Open        High         Low       Close  \
# Datetime
# 2023-06-20 09:30:00-04:00  184.410004  184.919998  184.410004  184.779999
# 2023-06-20 09:31:00-04:00  184.779999  185.268799  184.770004  185.050003
# 2023-06-20 09:32:00-04:00  185.039993  185.479996  185.020004  185.380005
# 2023-06-20 09:33:00-04:00  185.375000  185.662003  185.270004  185.559998
# 2023-06-20 09:34:00-04:00  185.540100  185.779999  185.520004  185.757599
# ...                               ...         ...         ...         ...
# 2023-06-26 13:32:00-04:00  185.830002  185.910004  185.830002  185.889999
# 2023-06-26 13:33:00-04:00  185.900497  185.990005  185.875000  185.942200
# 2023-06-26 13:34:00-04:00  185.949997  185.970001  185.894806  185.899002
# 2023-06-26 13:35:00-04:00  185.899994  185.960007  185.890793  185.949997
# 2023-06-26 13:36:00-04:00  185.870499  185.870499  185.870499  185.870499
#
# ...

# %%
intraday_data_Meta = yf.download(tickers='Meta', period='5d', interval='1m', auto_adjust=True)
intraday_data_Meta
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                  Open        High         Low       Close  \
# Datetime
# 2023-06-20 09:30:00-04:00  278.730011  279.700012  278.559998  279.609985
# 2023-06-20 09:31:00-04:00  279.700012  280.600006  279.657104  280.369995
# 2023-06-20 09:32:00-04:00  280.359985  281.100006  279.980011  281.019989
# 2023-06-20 09:33:00-04:00  281.010010  281.149994  280.230011  280.230011
# 2023-06-20 09:34:00-04:00  280.290009  280.535004  279.540009  279.540009
# ...                               ...         ...         ...         ...
# 2023-06-26 13:32:00-04:00  279.515015  279.760010  279.420013  279.760010
# 2023-06-26 13:33:00-04:00  279.739990  280.569885  279.739990  280.524994
# 2023-06-26 13:34:00-04:00  280.549988  280.570007  280.179993  280.209991
# 2023-06-26 13:35:00-04:00  280.182007  280.619904  280.182007  280.290100
# 2023-06-26 13:36:00-04:00  279.831299  279.831299  279.831299  279.831299
#
# ...

# %%
intraday_data_NVDA = yf.download(tickers='NVDA', period='5d', interval='1m', auto_adjust=True)
intraday_data_NVDA
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                  Open        High         Low       Close  \
# Datetime
# 2023-06-20 09:30:00-04:00  429.980011  430.910004  428.548615  429.489990
# 2023-06-20 09:31:00-04:00  429.477692  430.839996  429.089996  429.329987
# 2023-06-20 09:32:00-04:00  429.259613  430.649994  429.259613  430.295990
# 2023-06-20 09:33:00-04:00  430.220001  431.660004  429.700012  430.839996
# 2023-06-20 09:34:00-04:00  430.610809  431.839996  430.559998  431.593994
# ...                               ...         ...         ...         ...
# 2023-06-26 13:32:00-04:00  405.929993  406.299988  405.929993  406.132599
# 2023-06-26 13:33:00-04:00  406.149994  407.070007  406.079987  406.820007
# 2023-06-26 13:34:00-04:00  406.829987  406.879913  406.234985  406.278412
# 2023-06-26 13:35:00-04:00  406.302002  406.609985  406.109985  406.570007
# 2023-06-26 13:36:00-04:00  406.029388  406.029388  406.029388  406.029388
#
# ...

# %%
intraday_data_TSLA = yf.download(tickers='TSLA', period='5d', interval='1m', auto_adjust=True)
intraday_data_TSLA
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                  Open        High         Low       Close  \
# Datetime
# 2023-06-20 09:30:00-04:00  261.500000  262.540009  261.119995  262.489990
# 2023-06-20 09:31:00-04:00  262.529999  263.500000  261.870087  263.088409
# 2023-06-20 09:32:00-04:00  263.079987  263.940002  262.779999  263.649994
# 2023-06-20 09:33:00-04:00  263.690002  264.480011  263.510010  264.399994
# 2023-06-20 09:34:00-04:00  264.329987  264.940002  264.272491  264.419891
# ...                               ...         ...         ...         ...
# 2023-06-26 13:32:00-04:00  245.801498  246.240005  245.800003  246.020004
# 2023-06-26 13:33:00-04:00  246.024994  246.300003  245.960098  246.228500
# 2023-06-26 13:34:00-04:00  246.249695  246.306793  245.820007  245.850006
# 2023-06-26 13:35:00-04:00  245.850006  245.940002  245.160004  245.229996
# 2023-06-26 13:36:00-04:00  244.895004  244.895004  244.895004  244.895004
#
# ...

# %%
intraday_data_Google = yf.download(tickers='GOOGL', period='5d', interval='1m', auto_adjust=True)
intraday_data_Google
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                  Open        High         Low       Close  \
# Datetime
# 2023-06-20 09:30:00-04:00  122.930000  123.400002  122.790001  123.300003
# 2023-06-20 09:31:00-04:00  123.329002  123.480003  123.220001  123.370003
# 2023-06-20 09:32:00-04:00  123.360100  123.699997  123.190002  123.669998
# 2023-06-20 09:33:00-04:00  123.639999  123.800003  123.180000  123.195000
# 2023-06-20 09:34:00-04:00  123.190002  123.410004  123.190002  123.355003
# ...                               ...         ...         ...         ...
# 2023-06-26 13:32:00-04:00  118.775002  118.820000  118.760002  118.815002
# 2023-06-26 13:33:00-04:00  118.820000  118.919998  118.820000  118.899101
# 2023-06-26 13:34:00-04:00  118.889999  118.900002  118.820000  118.820000
# 2023-06-26 13:35:00-04:00  118.830002  118.934998  118.830002  118.885002
# 2023-06-26 13:36:00-04:00  118.739998  118.739998  118.739998  118.739998
#
# ...

# %%
#amazon, netflix, IBM, MSFT, VOO, KO would be left

# %%
column_dict = {
    'Open':'first', #matches open price to first float downloaded in dataset
    'High':'max',
    'Low':'min',
    'Close':'last',
    'Volume':'sum'
}
#by making this dictionary we can also use it to organize any stock dataset we download and want to 
#look at the necessary information we want

# %%
#next we will convert 1-min data into 1-hr data by resampling 
intraday_data_AAPL = yf.download(tickers='AAPL', period='5d', interval='1m', auto_adjust=True)
intraday_data_AAPL

column_dict = {
    'Open':'first', #matches open price to first float downloaded in dataset
    'High':'max',
    'Low':'min',
    'Close':'last',
    'Volume':'sum'
}

intraday_data_AAPL_10 = intraday_data_AAPL.resample("10T").agg(column_dict)
intraday_data_AAPL_10
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                  Open        High         Low       Close  \
# Datetime
# 2023-06-20 09:30:00-04:00  184.410004  186.100006  184.410004  186.059998
# 2023-06-20 09:40:00-04:00  186.059998  186.070007  185.600006  185.789993
# 2023-06-20 09:50:00-04:00  185.839996  185.854996  185.229996  185.304993
# 2023-06-20 10:00:00-04:00  185.304993  185.800003  185.210007  185.684998
# 2023-06-20 10:10:00-04:00  185.679993  185.970001  185.160004  185.219406
# ...                               ...         ...         ...         ...
# 2023-06-26 12:50:00-04:00  185.779999  186.070007  185.690002  186.050003
# 2023-06-26 13:00:00-04:00  186.050003  186.050003  185.712708  185.869995
# 2023-06-26 13:10:00-04:00  185.880005  185.960007  185.710007  185.820007
# 2023-06-26 13:20:00-04:00  185.820007  185.994995  185.610901  185.985001
# 2023-06-26 13:30:00-04:00  186.000000  186.009995  185.823700  185.869995
#
# ...

# %%
intraday_data_Meta = yf.download(tickers='Meta', period='5d', interval='1m', auto_adjust=True)
intraday_data_Meta

column_dict = {
    'Open':'first', #matches open price to first float downloaded in dataset
    'High':'max',
    'Low':'min',
    'Close':'last',
    'Volume':'sum'
}

intraday_data_Meta_10 = intraday_data_Meta.resample("10T").agg(column_dict)
intraday_data_Meta_10
#looks like 10 minute intervals everyday of the week
#make a def func to call companies to structure easier
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                  Open        High         Low       Close  \
# Datetime
# 2023-06-20 09:30:00-04:00  278.730011  281.160004  278.559998  281.135803
# 2023-06-20 09:40:00-04:00  281.109985  281.589996  280.450012  281.420013
# 2023-06-20 09:50:00-04:00  281.375000  281.410004  278.799988  278.924988
# 2023-06-20 10:00:00-04:00  278.880005  279.160004  278.179993  278.190002
# 2023-06-20 10:10:00-04:00  278.209991  278.870514  277.809998  278.320007
# ...                               ...         ...         ...         ...
# 2023-06-26 12:50:00-04:00  278.682404  279.029999  278.130005  278.579987
# 2023-06-26 13:00:00-04:00  278.639801  278.769897  278.040100  278.089996
# 2023-06-26 13:10:00-04:00  278.089996  278.890015  277.600006  278.290009
# 2023-06-26 13:20:00-04:00  278.255005  279.279999  277.899994  279.144989
# 2023-06-26 13:30:00-04:00  279.149994  280.619904  279.125000  279.890015
#
# ...

# %%
close_price = intraday_data_AAPL['Close']
mavg = close_price.rolling(100).mean()
mavg
#moving average for the last week of trading
# Out:
# Datetime
# 2023-06-20 09:30:00-04:00           NaN
# 2023-06-20 09:31:00-04:00           NaN
# 2023-06-20 09:32:00-04:00           NaN
# 2023-06-20 09:33:00-04:00           NaN
# 2023-06-20 09:34:00-04:00           NaN
#                                 ...
# 2023-06-26 13:32:00-04:00    186.133871
# 2023-06-26 13:33:00-04:00    186.123908
# 2023-06-26 13:34:00-04:00    186.113026
# 2023-06-26 13:35:00-04:00    186.104826
# 2023-06-26 13:36:00-04:00    186.095127
# Name: Close, Length: 1805, dtype: float64

# %%
help(close_price.rolling)
# Out:
# Help on method rolling in module pandas.core.generic:
#
# rolling(window: 'int | timedelta | BaseOffset | BaseIndexer', min_periods: 'int | None' = None, center: 'bool_t' = False, win_type: 'str | None' = None, on: 'str | None' = None, axis: 'Axis' = 0, closed: 'str | None' = None, method: 'str' = 'single') method of pandas.core.series.Series instance
#     Provide rolling window calculations.
#
#     Parameters
#     ----------
#     window : int, offset, or BaseIndexer subclass
#         Size of the moving window.
#
#         If an integer, the fixed number of observations used for
#         each window.
#
#         If an offset, the time period of each window. Each
#         window will be a variable sized based on the observations included in
#         the time-period. This is only valid for datetimelike indexes.
#         To learn more about the offsets & frequency strings, please see `this link
# ...

# %%
# %matplotlib inline
from matplotlib import style
import matplotlib as mpl
mpl.rc('figure', figsize=(8,7))
mpl.__version__

style.use("ggplot")
close_price.plot(label='AAPL')
mavg.plot(label='mavg')
plt.legend()

# %%
#Return deviation--to determine risk and return 

#expected return measures the mean, or expected value, of the probability distribution of investment returns. 
#the expected return of a portfolio is calculated by multiplying the weight of each asset by its expected return...
#...and adding the values for each investment
returns = close_price / close_price.shift(1) - 1
returns.plot(label='return')
# Out:
# <AxesSubplot:xlabel='Datetime'>

# %%
start_date = '2013-01-01'
end_date = '2023-01-01'

symbols_list = ['AAPL','META','NVDA','TSLA','GOOGL','AMZN','IBM','KO','MSFT',"VTI"]

data_set_competitors = pd.DataFrame(columns=symbols_list)

for symbol in symbols_list:
    data_set_competitors[symbol] = yf.download(symbol, start_date, end_date)['Close']
    
data_set_competitors
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#                   AAPL        META        NVDA        TSLA      GOOGL  \
# Date
# 2013-01-02   19.608213   28.000000    3.180000    2.357333  18.099348
# 2013-01-03   19.360714   27.770000    3.182500    2.318000  18.109859
# ...

# %%
#analyzing AAPL against other tech giants
data_set_competitors.plot(figsize=(10,7))
plt.legend()
plt.title("Adjusted Close Price", fontsize=16)
plt.ylabel("Price ($)", fontsize=14)
plt.xlabel("Year", fontsize=14)
plt.grid(which='major', color='k', linestyle='-.', linewidth=0.5)
plt.show()

# %%
#correlation analysis--Does one competitor affect another? 
#we can analyze the competition by percentage change and correlation function in pandas.
#percentage change will find how much the price changes compared to the previous day which defines returns
returnscompetition = data_set_competitors.pct_change()
correlation = returnscompetition.corr()
correlation #prints in matrix formation
# Out:
#            AAPL      META      NVDA      TSLA     GOOGL      AMZN       IBM  \
# AAPL   1.000000  0.481493  0.536683  0.368070  0.573100  0.506421  0.395308
# META   0.481493  1.000000  0.457914  0.315653  0.597218  0.542981  0.257128
# NVDA   0.536683  0.457914  1.000000  0.385391  0.550248  0.504516  0.337009
# TSLA   0.368070  0.315653  0.385391  1.000000  0.361737  0.373477  0.204669
# GOOGL  0.573100  0.597218  0.550248  0.361737  1.000000  0.628897  0.416225
# AMZN   0.506421  0.542981  0.504516  0.373477  0.628897  1.000000  0.294746
# IBM    0.395308  0.257128  0.337009  0.204669  0.416225  0.294746  1.000000
# KO     0.344170  0.222732  0.242365  0.179247  0.371207  0.241261  0.462608
# MSFT   0.625999  0.510396  0.591984  0.374869  0.696668  0.595937  0.454870
# VTI    0.695097  0.570770  0.646385  0.450325  0.724498  0.604443  0.627584
#
#              KO      MSFT       VTI
# AAPL   0.344170  0.625999  0.695097
# META   0.222732  0.510396  0.570770
# ...

# %%
#because VTI is apple's highest share holder it makes sense its almost 70%. but for MSFT being highest competitor
#lets do a scatterplot of apple's return distributions vs microsoft
plt.scatter(returnscompetition.AAPL, returnscompetition.MSFT)
plt.xlabel('Returns from AAPL')
plt.ylabel("Returns from MSFT")
# Out:
# Text(0, 0.5, 'Returns from MSFT')

# %%
#there is a pretty positive linear correlation, the higher apple the higher is msft
#we are going to run a Kernel Density Estimate of this, it is a fundamental data smoothing problem
#inferences about the pobulation are made, based on a finite data sample. it helps generate estimations of the overall
#distributions
pd.plotting.scatter_matrix(returnscompetition, diagonal='kde', figsize=(10,10));

# %%
#In order to prove positive correlations, we will use heat maps to visualize the correlation ranges among comp stock
#lighter the color the more correlated the two stocks are.
plt.imshow(correlation, cmap='hot', interpolation='none')
plt.colorbar()
plt.xticks(range(len(correlation)), correlation.columns)
plt.yticks(range(len(correlation)), correlation.columns);

# %%
#from scatter matrix and heatmap, we can find great correlations among the competing stocks. 
#however this does not show causality, just that there is a trend in the tech space among competiting stocks
#rather than how competiting stocks affect each other

#A GOOD PLACE TO UPGRADE THIS WOULD BE HOW DO COMPETITING STOCKS AFFECT ONE ANOTHER

# %%
#stock returns rate and risk
#we'll analyze risk and returns with avg return rate and standard deviation of returns
plt.scatter(returnscompetition.mean(), returnscompetition.std())
plt.xlabel('Expected returns')
plt.ylabel('Risk')
for label, x, y, in zip (returnscompetition.columns, returnscompetition.mean(), returnscompetition.std()):
    plt.annotate(
        label,
        xy = (x, y), xytext = (20, -20),
        textcoords = 'offset points', ha = 'right', va = 'bottom', 
        bbox = dict(boxstyle = 'round, pad=0.5', fc='yellow', alpha=0.5),
        arrowprops = dict(arrowstyle = '->', connectionstyle='arc3, rad=0'))

# %%
#Predicting Stocks Price
#we're going to use Simple Linear Analysis, Quadratic Discriminant Analysis (QDA), and KNN
#we'll first add high low percentage and percentage change
df_regular_AAPL = apple_data_df.loc[:,['Adj Close', 'Volume']]
df_regular_AAPL["HL_PCT"] = (apple_data_df['High'] - apple_data_df['Low']) / apple_data_df['Close'] * 100.0
#high low percent change = high - low / close (total) * 100
df_regular_AAPL['PCT_Change'] = (apple_data_df["Close"] - apple_data_df['Open']) / apple_data_df['Open'] * 100.0

# %%
df_regular_AAPL #yearly by month
# Out:
#              Adj Close     Volume    HL_PCT  PCT_Change
# Date
# 2016-01-04   24.041487  270597600  3.198864    2.670303
# 2016-01-05   23.439018  223164000  3.349231   -2.874705
# 2016-01-06   22.980326  273829600  2.482622    0.139220
# 2016-01-07   22.010450  324377600  3.836182   -2.259833
# 2016-01-08   22.126835  283192000  2.423678   -1.613398
# ...                ...        ...       ...         ...
# 2022-12-23  131.477127   63814900  2.108296    0.717998
# 2022-12-27  129.652435   69007800  2.068755   -1.027558
# 2022-12-28  125.674026   85438400  4.093935   -2.799412
# 2022-12-29  129.233658   75703700  2.121744    1.265726
# 2022-12-30  129.552719   77034200  1.939503    1.183700
#
# [1762 rows x 4 columns]

# %%
import numpy as np
import math
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import Ridge
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split
from sklearn import datasets
from sklearn import preprocessing, svm
#preprocessing & Cross Validation
#first drop missing values
df_regular_AAPL.fillna(value=-99999, inplace=True)
print(df_regular_AAPL.shape)

#we want to separate 1 percent of the data to forecast
forecast_out = int(math.ceil(0.01*len(df_regular_AAPL)))

#separating the label, we want to predict adj close
forecast_close = 'Adj Close'
df_regular_AAPL['label'] = df_regular_AAPL[forecast_close].shift(-forecast_out)
X = np.array(df_regular_AAPL.drop(['label'],1))

#scale the X so that everyone can have the same distribution for linear regression
X = preprocessing.scale(X)

#find data series of late X and early X by training for model generation and evaluation
X_lately = X[-forecast_out:]
X = X[:-forecast_out]

#separate label and identify it as target y
y = np.array(df_regular_AAPL['label'])
y = y[:-forecast_out]

print('Dimension of X', X.shape)
print('Dimension of y', y.shape)
# Out:
# (1762, 4)
# Dimension of X (1744, 4)
# Dimension of y (1744,)
# /var/folders/hw/r_q5t6hd2r71fj7t3zwm74kc0000gn/T/ipykernel_97111/2334873208.py:22: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X = np.array(df_regular_AAPL.drop(['label'],1))

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
#separation of training and testing of model by cross validation train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
clfreg = LinearRegression(n_jobs=-1)
clfreg.fit(X_train, y_train)

clfpoly2 = make_pipeline(PolynomialFeatures(2), Ridge())
clfpoly2.fit(X_train, y_train)

clfpoly3 = make_pipeline(PolynomialFeatures(3), Ridge())
clfpoly3.fit(X_train, y_train)
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Pipeline(steps=[('polynomialfeatures', PolynomialFeatures(degree=3)),
#                 ('ridge', Ridge())])

# %%
#KNN regression
clfknn = KNeighborsRegressor(n_neighbors=2)
clfknn.fit(X_train, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=2)

# %%
#evaluation
confidence_reg = clfreg.score(X_test, y_test)
confidencepoly2 = clfpoly2.score(X_test, y_test)
confidencepoly3 = clfpoly3.score(X_test, y_test)
confidenceknn = clfknn.score(X_test, y_test)

#results
print("The linear regression confidence is ", confidence_reg)
print("The quadratic regression 2 confidence is ", confidencepoly2)
print("The quadratic regression 3 confidence is ", confidencepoly3)
print("The KNN regression confidence is ", confidenceknn)
# Out:
# The linear regression confidence is  0.9791904008501857
# The quadratic regression 2 confidence is  0.9811873942671367
# The quadratic regression 3 confidence is  0.9811301505240183
# The KNN regression confidence is  0.9556700612331193

# %%
forecast_set_knn = clfknn.predict(X_lately)
df_regular_AAPL['Forecast'] = np.nan
print(forecast_set_knn, confidenceknn, forecast_out)
# Out:
# [144.64126587 134.91210938 136.40623474 145.46141815 166.47621918
#  158.56007385 146.6678772  153.97920227 111.92897415 135.77395248
#  148.72501373 146.89541626 135.02210999 150.78330231 121.44417572
#  144.64126587 137.871521   132.20574188] 0.9556700612331193 18

# %%
#plotting predictions
last_date = df_regular_AAPL.iloc[-1].name
last_unix = last_date
next_unix = last_unix + datetime.timedelta(days=1)

for i in forecast_set_knn:
    next_date = next_unix
    next_unix += datetime.timedelta(days=1)
    df_regular_AAPL.loc[next_date] = [np.nan for _ in range(len(df_regular_AAPL.columns)-1)]+[i]

# %%
df_regular_AAPL['Adj Close'].tail(500).plot()
df_regular_AAPL['Forecast'].tail(500).plot()
plt.legend(loc=4)
plt.xlabel("Date")
plt.ylabel("Price ($)")
plt.show()

# %%
#next steps assuming economic qualitative factors such as news(news sourcing and sentimal analysis)
#assuming economic quantitative factors such as HPI of certain country economic inequality among origin of company
#cleaning out the data
#import data files

# %%
start_date = '2021-01-01'
end_date = '2023-01-01'

symbol = 'AAPL'
apple_data_df = yf.download(symbol, start_date, end_date)

apple_data_df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-01-04  133.520004  133.610001  126.760002  129.410004  127.503616
# 2021-01-05  128.889999  131.740005  128.429993  131.009995  129.080093
# 2021-01-06  127.720001  131.050003  126.379997  126.599998  124.735023
# 2021-01-07  128.360001  131.630005  127.860001  130.919998  128.991379
# 2021-01-08  132.429993  132.630005  130.229996  132.050003  130.104752
# ...                ...         ...         ...         ...         ...
# 2022-12-23  130.919998  132.419998  129.639999  131.860001  131.477127
# 2022-12-27  131.380005  131.410004  128.720001  130.029999  129.652435
# 2022-12-28  129.669998  131.029999  125.870003  126.040001  125.674026
# 2022-12-29  127.989998  130.479996  127.730003  129.610001  129.233658
# 2022-12-30  128.410004  129.949997  127.430000  129.929993  129.552719
#
#                Volume
# Date
# ...

# %%
apple_data_df['Close'].plot(figsize=(10,7))
plt.title("Apple Data (2020-2023)", fontsize=14)
plt.ylabel("Price ($)", fontsize=12)
plt.xlabel("Month ", fontsize=12)
plt.grid(which='major', color='k', linestyle='-.', linewidth=0.5)
plt.show()
