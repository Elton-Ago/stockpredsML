# %%
import alpaca_trade_api as tradeapi
import matplotlib.pyplot as plt
import config as cf
from alpaca_trade_api.rest import REST, TimeFrame
from alpaca_trade_api.common import URL
from alpaca_trade_api.stream import Stream
import numpy as np
import pandas as pd

# %%
base_urL= "https://paper-api.alpaca.markets"
base_url1 = "https://data.alpaca.markets"
alpaca_api_key = "PK2VVCQIOCPEDH6OSTTS"
alpaca_secret_key = "depW27g3IjSwAJEmlmZbH5Y1Vk4JY7UZCFingw54"

# %%
api = tradeapi.REST(key_id = alpaca_api_key, secret_key = alpaca_secret_key, base_url = base_urL, api_version = 'v2')

# %%
account = api.get_account()

# %%
print(account.id, account.equity, account.status)
# Out:
# a591b9e4-df81-4652-973d-ccf331202ca9 100000 ACTIVE

# %%
api.get_bars("AAPL", TimeFrame.Hour, "2020-01-01","2022-10-21",adjustment='raw').df
# Out:
#                                open      high      low     close    volume  \
# timestamp
# 2020-01-02 09:00:00+00:00  295.0500  295.7500  295.050  295.7300     26138
# 2020-01-02 10:00:00+00:00  295.7500  296.0500  295.750  296.0000     15543
# 2020-01-02 11:00:00+00:00  295.7500  295.8500  295.300  295.5100     14890
# 2020-01-02 12:00:00+00:00  295.5000  296.1800  295.130  296.1000    134301
# 2020-01-02 13:00:00+00:00  295.8898  296.7500  295.435  296.6803    215866
# ...                             ...       ...      ...       ...       ...
# 2022-10-21 19:00:00+00:00  146.6500  147.8479  146.600  147.2700  16866635
# 2022-10-21 20:00:00+00:00  147.2700  147.6399  147.270  147.5400   8015544
# 2022-10-21 21:00:00+00:00  147.5200  147.6700  147.270  147.5900    568656
# 2022-10-21 22:00:00+00:00  147.6300  147.6500  147.560  147.5700     42643
# 2022-10-21 23:00:00+00:00  147.6300  147.7500  147.580  147.5800     45210
#
#                            trade_count        vwap
# timestamp
# 2020-01-02 09:00:00+00:00          191  295.438169
# 2020-01-02 10:00:00+00:00          146  295.947596
# 2020-01-02 11:00:00+00:00          163  295.580787
# 2020-01-02 12:00:00+00:00         1219  295.835031
# 2020-01-02 13:00:00+00:00         2080  296.239297
# ...                                ...         ...
# 2022-10-21 19:00:00+00:00       133242  147.383634
# 2022-10-21 20:00:00+00:00         2821  147.275966
# 2022-10-21 21:00:00+00:00          944  147.301136
# 2022-10-21 22:00:00+00:00          585  147.596631
# 2022-10-21 23:00:00+00:00          769  147.678852
#
# [11658 rows x 7 columns]

# %%
def process_bar(bar):
    print(bar)#process bar
    
bar_iter=api.get_bars_iter("AAPL",TimeFrame.Hour,"2020-01-01","2022-10-21",adjustment='raw')
for bar in bar_iter:
    process_bar(bar)
# Out:
# Bar({   'c': 295.73,
#     'h': 295.75,
#     'l': 295.05,
#     'n': 191,
#     'o': 295.05,
#     't': '2020-01-02T09:00:00Z',
#     'v': 26138,
#     'vw': 295.438169})
# Bar({   'c': 296,
#     'h': 296.05,
#     'l': 295.75,
#     'n': 146,
#     'o': 295.75,
#     't': '2020-01-02T10:00:00Z',
#     'v': 15543,
#     'vw': 295.947596})
# Bar({   'c': 295.51,
#     'h': 295.85,
#     'l': 295.3,
#     'n': 163,
#     'o': 295.75,
#     't': '2020-01-02T11:00:00Z',
#     'v': 14890,
#     'vw': 295.580787})
# Bar({   'c': 296.1,
#     'h': 296.18,
#     'l': 295.13,
#     'n': 1219,
#     'o': 295.5,
#     't': '2020-01-02T12:00:00Z',
#     'v': 134301,
#     'vw': 295.835031})
# Bar({   'c': 296.6803,
#     'h': 296.75,
#     'l': 295.435,
#     'n': 2080,
#     'o': 295.8898,
#     't': '2020-01-02T13:00:00Z',
#     'v': 215866,
#     'vw': 296.239297})
# Bar({   'c': 297.97,
#     'h': 298.15,
#     'l': 295.19,
#     'n': 50653,
#     'o': 296.69,
#     't': '2020-01-02T14:00:00Z',
#     'v': 5985038,
#     'vw': 296.974978})
# Bar({   'c': 298.11,
#     'h': 298.41,
#     'l': 296.595,
#     'n': 51603,
#     'o': 297.99,
#     't': '2020-01-02T15:00:00Z',
#     'v': 5958547,
#     'vw': 297.62335})
# Bar({   'c': 298.41,
#     'h': 298.75,
#     'l': 297.45,
#     'n': 37273,
#     'o': 298.1163,
#     't': '2020-01-02T16:00:00Z',
#     'v': 4225029,
#     'vw': 298.217662})
# Bar({   'c': 298.7007,
#     'h': 298.8,
#     'l': 298.05,
#     'n': 25524,
#     'o': 298.41,
#     't': '2020-01-02T17:00:00Z',
#     'v': 2532722,
#     'vw': 298.501784})
# Bar({   'c': 298.4558,
#     'h': 298.73,
#     'l': 298.1,
#     'n': 20934,
#     'o': 298.707,
#     't': '2020-01-02T18:00:00Z',
#     'v': 2059528,
#     'vw': 298.398232})
# Bar({   'c': 299.08,
#     'h': 299.157,
#     'l': 298.06,
#     'n': 29260,
#     'o': 298.45,
#     't': '2020-01-02T19:00:00Z',
#     'v': 3014292,
#     'vw': 298.677561})
# Bar({   'c': 300.5904,
#     'h': 300.6,
#     'l': 299.04,
#     'n': 60484,
#     'o': 299.08,
#     't': '2020-01-02T20:00:00Z',
#     'v': 6539227,
#     'vw': 299.754014})
# Bar({   'c': 300.9,
#     'h': 300.93,
#     'l': 300.32,
#     'n': 1544,
#     'o': 300.58,
#     't': '2020-01-02T21:00:00Z',
#     'v': 3083867,
#     'vw': 300.358346})
# Bar({   'c': 300.76,
#     'h': 300.94,
#     'l': 300.7,
#     'n': 642,
#     'o': 300.94,
#     't': '2020-01-02T22:00:00Z',
#     'v': 45330,
#     'vw': 300.826724})
# Bar({   'c': 300.7701,
#     'h': 300.9,
#     'l': 300.76,
#     'n': 135,
#     'o': 300.85,
#     't': '2020-01-02T23:00:00Z',
#     'v': 14532,
#     'vw': 300.823409})
# Bar({   'c': 301.19,
#     'h': 301.19,
#     'l': 300.78,
#     'n': 336,
#     'o': 300.8,
#     't': '2020-01-03T00:00:00Z',
#     'v': 37950,
#     'vw': 300.97104})
# Bar({   'c': 296.2,
#     'h': 297.35,
#     'l': 295.6,
#     'n': 568,
#     'o': 297.35,
#     't': '2020-01-03T09:00:00Z',
#     'v': 56210,
#     'vw': 296.177743})
# Bar({   'c': 294.84,
#     'h': 296.6,
#     'l': 294.38,
#     'n': 459,
#     'o': 296.18,
#     't': '2020-01-03T10:00:00Z',
#     'v': 44501,
#     'vw': 295.460827})
# Bar({   'c': 295.67,
#     'h': 295.9,
#     'l': 294.83,
#     'n': 494,
#     'o': 294.84,
#     't': '2020-01-03T11:00:00Z',
#     'v': 55244,
#     'vw': 295.426055})
# Bar({   'c': 298.05,
#     'h': 298.2,
#     'l': 295.6,
#     'n': 2525,
#     'o': 295.79,
#     't': '2020-01-03T12:00:00Z',
#     'v': 302905,
#     'vw': 297.080715})
# Bar({   'c': 297.59,
#     'h': 298.6,
#     'l': 295.65,
#     'n': 3859,
#     'o': 298.01,
#     't': '2020-01-03T13:00:00Z',
#     'v': 802977,
#     'vw': 298.765377})
# Bar({   'c': 299.2016,
#     'h': 300.5699,
#     'l': 296.5,
#     'n': 63819,
#     'o': 297.52,
#     't': '2020-01-03T14:00:00Z',
#     'v': 8044368,
#     'vw': 298.974365})
# Bar({   'c': 298.64,
#     'h': 299.6,
#     'l': 297.6,
#     'n': 48183,
#     'o': 299.18,
#     't': '2020-01-03T15:00:00Z',
#     'v': 5440322,
#     'vw': 298.728119})
# Bar({   'c': 299.35,
#     'h': 299.84,
#     'l': 297.94,
#     'n': 32329,
#     'o': 298.66,
#     't': '2020-01-03T16:00:00Z',
#     'v': 3651862,
#     'vw': 298.784223})
# Bar({   'c': 300.1903,
#     'h': 300.58,
#     'l': 299.31,
#     'n': 28816,
#     'o': 299.35,
#     't': '2020-01-03T17:00:00Z',
#     'v': 3406681,
#     'vw': 299.930489})
# Bar({   'c': 299.3859,
#     'h': 300.39,
#     'l': 298.77,
#     'n': 26220,
#     'o': 300.22,
#     't': '2020-01-03T18:00:00Z',
#     'v': 2961022,
#     'vw': 299.703312})
# Bar({   'c': 299.825,
#     'h': 299.94,
#     'l': 298.83,
#     'n': 20729,
#     'o': 299.3757,
#     't': '2020-01-03T19:00:00Z',
#     'v': 2169900,
#     'vw': 299.3703})
# Bar({   'c': 297.38,
#     'h': 300.04,
#     'l': 297.35,
#     'n': 50103,
#     'o': 299.81,
#     't': '2020-01-03T20:00:00Z',
#     'v': 5631074,
#     'vw': 298.487102})
# Bar({   'c': 297.52,
#     'h': 297.88,
#     'l': 297.43,
#     'n': 1617,
#     'o': 297.43,
#     't': '2020-01-03T21:00:00Z',
#     'v': 3966783,
#     'vw': 297.435832})
# Bar({   'c': 297.6,
#     'h': 297.66,
#     'l': 297.47,
#     'n': 369,
#     'o': 297.65,
#     't': '2020-01-03T22:00:00Z',
#     'v': 31953,
#     'vw': 297.557722})
# Bar({   'c': 297.7,
#     'h': 297.8,
#     'l': 297.63,
#     'n': 120,
#     'o': 297.63,
#     't': '2020-01-03T23:00:00Z',
#     'v': 16388,
#     'vw': 297.689485})
# Bar({   'c': 297.32,
#     'h': 297.65,
#     'l': 297.31,
#     'n': 261,
#     'o': 297.65,
#     't': '2020-01-04T00:00:00Z',
#     'v': 34500,
#     'vw': 297.468796})
# Bar({   'c': 294.9,
#     'h': 295.51,
#     'l': 293.96,
#     'n': 436,
#     'o': 295.43,
#     't': '2020-01-06T09:00:00Z',
#     'v': 34114,
#     'vw': 294.423688})
# Bar({   'c': 294.95,
#     'h': 295.3,
#     'l': 294.69,
#     'n': 117,
#     'o': 294.9,
#     't': '2020-01-06T10:00:00Z',
#     'v': 16502,
#     'vw': 294.918047})
# Bar({   'c': 294.7,
#     'h': 295.12,
#     'l': 293.9,
#     'n': 283,
#     'o': 294.71,
#     't': '2020-01-06T11:00:00Z',
#     'v': 34604,
#     'vw': 294.589239})
# Bar({   'c': 294.75,
#     'h': 295.5,
#     'l': 294.41,
#     'n': 1612,
#     'o': 294.74,
#     't': '2020-01-06T12:00:00Z',
#     'v': 175349,
#     'vw': 294.872778})
# Bar({   'c': 294.6,
#     'h': 295.4998,
#     'l': 294.28,
#     'n': 2699,
#     'o': 295.05,
#     't': '2020-01-06T13:00:00Z',
#     'v': 322316,
#     'vw': 294.730594})
# Bar({   'c': 296.84,
#     'h': 296.99,
#     'l': 292.75,
#     'n': 52779,
#     'o': 294.5,
#     't': '2020-01-06T14:00:00Z',
#     'v': 6492381,
#     'vw': 295.087043})
# Bar({   'c': 298.04,
#     'h': 298.239,
#     'l': 296.2254,
#     'n': 40036,
#     'o': 296.88,
#     't': '2020-01-06T15:00:00Z',
#     'v': 4556685,
#     'vw': 297.223775})
# Bar({   'c': 298.458,
#     'h': 299.64,
#     'l': 297.65,
#     'n': 35154,
#     'o': 298.07,
#     't': '2020-01-06T16:00:00Z',
#     'v': 4208688,
#     'vw': 298.881486})
# Bar({   'c': 298.125,
#     'h': 298.46,
#     'l': 297.14,
#     'n': 23795,
#     'o': 298.44,
#     't': '2020-01-06T17:00:00Z',
#     'v': 2697864,
#     'vw': 297.847558})
# Bar({   'c': 299.1932,
#     'h': 299.37,
#     'l': 298.04,
#     'n': 20627,
#     'o': 298.1549,
#     't': '2020-01-06T18:00:00Z',
#     'v': 2172263,
#     'vw': 298.766616})
# Bar({   'c': 299.38,
#     'h': 299.96,
#     'l': 298.98,
#     'n': 25262,
#     'o': 299.19,
#     't': '2020-01-06T19:00:00Z',
#     'v': 2779158,
#     'vw': 299.386831})
# Bar({   'c': 299.78,
#     'h': 299.88,
#     'l': 298.94,
#     'n': 36929,
#     'o': 299.3825,
#     't': '2020-01-06T20:00:00Z',
#     'v': 4231696,
#     'vw': 299.461486})
# Bar({   'c': 299.57,
#     'h': 299.87,
#     'l': 293.02,
#     'n': 676,
#     'o': 299.8,
#     't': '2020-01-06T21:00:00Z',
#     'v': 1771404,
#     'vw': 299.793957})
# Bar({   'c': 299.54,
#     'h': 299.6899,
#     'l': 299.41,
#     'n': 272,
#     'o': 299.52,
#     't': '2020-01-06T22:00:00Z',
#     'v': 28828,
#     'vw': 299.568471})
# Bar({   'c': 299.01,
#     'h': 299.56,
#     'l': 299,
#     'n': 151,
#     'o': 299.54,
#     't': '2020-01-06T23:00:00Z',
#     'v': 21071,
#     'vw': 299.144971})
# Bar({   'c': 299.6,
#     'h': 299.68,
#     'l': 299.05,
#     'n': 192,
#     'o': 299.05,
#     't': '2020-01-07T00:00:00Z',
#     'v': 25094,
#     'vw': 299.48522})
# Bar({   'c': 300.5,
#     'h': 300.9,
#     'l': 300.12,
#     'n': 174,
#     'o': 300.49,
#     't': '2020-01-07T09:00:00Z',
#     'v': 19549,
#     'vw': 300.536975})
# Bar({   'c': 300.32,
#     'h': 300.49,
#     'l': 300.2,
#     'n': 69,
#     'o': 300.49,
#     't': '2020-01-07T10:00:00Z',
#     'v': 17048,
#     'vw': 300.287492})
# Bar({   'c': 299.91,
#     'h': 300.45,
#     'l': 299.84,
#     'n': 193,
#     'o': 300.33,
#     't': '2020-01-07T11:00:00Z',
#     'v': 28567,
#     'vw': 300.20669})
# Bar({   'c': 300.56,
#     'h': 300.66,
#     'l': 299.9,
#     'n': 742,
#     'o': 300,
#     't': '2020-01-07T12:00:00Z',
#     'v': 114376,
#     'vw': 300.309798})
# Bar({   'c': 299.565,
#     'h': 300.6,
#     'l': 299.39,
#     'n': 1636,
#     'o': 299.99,
#     't': '2020-01-07T13:00:00Z',
#     'v': 209471,
#     'vw': 300.000944})
# Bar({   'c': 298.8245,
#     'h': 300.9,
#     'l': 297.75,
#     'n': 48640,
#     'o': 299.6,
#     't': '2020-01-07T14:00:00Z',
#     'v': 5738371,
#     'vw': 299.278718})
# Bar({   'c': 299.4031,
#     'h': 299.57,
#     'l': 297.48,
#     'n': 43633,
#     'o': 298.89,
#     't': '2020-01-07T15:00:00Z',
#     'v': 4999146,
#     'vw': 298.478858})
# Bar({   'c': 298.93,
#     'h': 299.8832,
#     'l': 298.55,
#     'n': 27688,
#     'o': 299.38,
#     't': '2020-01-07T16:00:00Z',
#     'v': 3549795,
#     'vw': 299.297335})
# Bar({   'c': 299.57,
#     'h': 299.65,
#     'l': 298.65,
#     'n': 20128,
#     'o': 298.9499,
#     't': '2020-01-07T17:00:00Z',
#     'v': 2079068,
#     'vw': 299.153778})
# Bar({   'c': 300.07,
#     'h': 300.41,
#     'l': 299.5735,
#     'n': 22843,
#     'o': 299.5735,
#     't': '2020-01-07T18:00:00Z',
#     'v': 2187401,
#     'vw': 299.955934})
# Bar({   'c': 299.002,
#     'h': 300.1,
#     'l': 298.96,
#     'n': 18588,
#     'o': 300.0745,
#     't': '2020-01-07T19:00:00Z',
#     'v': 1849068,
#     'vw': 299.292279})
# Bar({   'c': 298.27,
#     'h': 299.5643,
#     'l': 297.95,
#     'n': 35263,
#     'o': 299.01,
#     't': '2020-01-07T20:00:00Z',
#     'v': 3684585,
#     'vw': 298.87408})
# Bar({   'c': 297.9,
#     'h': 298.39,
#     'l': 297.39,
#     'n': 1291,
#     'o': 298.39,
#     't': '2020-01-07T21:00:00Z',
#     'v': 2268900,
#     'vw': 298.364063})
# Bar({   'c': 297.85,
#     'h': 298.39,
#     'l': 297.7001,
#     'n': 169,
#     'o': 297.85,
#     't': '2020-01-07T22:00:00Z',
#     'v': 289271,
#     'vw': 298.382384})
# Bar({   'c': 294.6,
#     'h': 298,
#     'l': 293.7,
#     'n': 2519,
#     'o': 297.76,
#     't': '2020-01-07T23:00:00Z',
#     'v': 279960,
#     'vw': 295.254917})
# Bar({   'c': 292.6,
#     'h': 294.69,
#     'l': 292,
#     'n': 3304,
#     'o': 294.56,
#     't': '2020-01-08T00:00:00Z',
#     'v': 383124,
#     'vw': 292.94443})
# Bar({   'c': 297.18,
#     'h': 297.38,
#     'l': 296.5,
#     'n': 381,
#     'o': 296.5,
#     't': '2020-01-08T09:00:00Z',
#     'v': 33518,
#     'vw': 296.973711})
# Bar({   'c': 298,
#     'h': 298,
#     'l': 297,
#     'n': 144,
#     'o': 297,
#     't': '2020-01-08T10:00:00Z',
#     'v': 13656,
#     'vw': 297.610904})
# Bar({   'c': 298.37,
#     'h': 298.75,
#     'l': 298,
#     'n': 222,
#     'o': 298.25,
#     't': '2020-01-08T11:00:00Z',
#     'v': 25457,
#     'vw': 298.363647})
# Bar({   'c': 298.47,
#     'h': 298.54,
#     'l': 297.6,
#     'n': 1056,
#     'o': 298.16,
#     't': '2020-01-08T12:00:00Z',
#     'v': 113575,
#     'vw': 298.095616})
# Bar({   'c': 298.1,
#     'h': 299.13,
#     'l': 297.55,
#     'n': 2124,
#     'o': 297.7,
#     't': '2020-01-08T13:00:00Z',
#     'v': 649681,
#     'vw': 298.374223})
# Bar({   'c': 298.37,
#     'h': 299.1,
#     'l': 296.93,
#     'n': 30611,
#     'o': 298.179,
#     't': '2020-01-08T14:00:00Z',
#     'v': 3826536,
#     'vw': 298.153485})
# Bar({   'c': 297.73,
#     'h': 298.76,
#     'l': 297.37,
#     'n': 30560,
#     'o': 298.38,
#     't': '2020-01-08T15:00:00Z',
#     'v': 3273764,
#     'vw': 298.180574})
# Bar({   'c': 300.09,
#     'h': 300.21,
#     'l': 297.5,
#     'n': 40123,
#     'o': 297.73,
#     't': '2020-01-08T16:00:00Z',
#     'v': 4923253,
#     'vw': 299.142778})
# Bar({   'c': 302.6313,
#     'h': 303.04,
#     'l': 300.0799,
#     'n': 47475,
#     'o': 300.09,
#     't': '2020-01-08T17:00:00Z',
#     'v': 5911958,
#     'vw': 301.830763})
# Bar({   'c': 302.6032,
#     'h': 303.23,
#     'l': 302.4,
#     'n': 26185,
#     'o': 302.645,
#     't': '2020-01-08T18:00:00Z',
#     'v': 2773401,
#     'vw': 302.839783})
# Bar({   'c': 303.07,
#     'h': 303.09,
#     'l': 302.53,
#     'n': 20745,
#     'o': 302.6,
#     't': '2020-01-08T19:00:00Z',
#     'v': 1970335,
#     'vw': 302.812021})
# Bar({   'c': 303.15,
#     'h': 304.4399,
#     'l': 302.24,
#     'n': 59422,
#     'o': 303.07,
#     't': '2020-01-08T20:00:00Z',
#     'v': 6564939,
#     'vw': 303.561277})
# Bar({   'c': 303.46,
#     'h': 303.69,
#     'l': 302.46,
#     'n': 1454,
#     'o': 303.19,
#     't': '2020-01-08T21:00:00Z',
#     'v': 2633505,
#     'vw': 303.191729})
# Bar({   'c': 303.34,
#     'h': 303.58,
#     'l': 303.19,
#     'n': 230,
#     'o': 303.47,
#     't': '2020-01-08T22:00:00Z',
#     'v': 285127,
#     'vw': 303.203783})
# Bar({   'c': 303.65,
#     'h': 303.88,
#     'l': 303.3,
#     'n': 290,
#     'o': 303.36,
#     't': '2020-01-08T23:00:00Z',
#     'v': 41578,
#     'vw': 303.657676})
# Bar({   'c': 303.99,
#     'h': 304,
#     'l': 303.6,
#     'n': 256,
#     'o': 303.7,
#     't': '2020-01-09T00:00:00Z',
#     'v': 41335,
#     'vw': 303.869858})
# Bar({   'c': 305.85,
#     'h': 305.96,
#     'l': 305.02,
#     'n': 170,
#     'o': 305.19,
#     't': '2020-01-09T09:00:00Z',
#     'v': 24226,
#     'vw': 305.708528})
# Bar({   'c': 305.69,
#     'h': 306,
#     'l': 305.4,
#     'n': 134,
#     'o': 305.83,
#     't': '2020-01-09T10:00:00Z',
#     'v': 21479,
#     'vw': 305.71849})
# Bar({   'c': 305.4,
#     'h': 305.85,
#     'l': 305.39,
#     'n': 115,
#     'o': 305.69,
#     't': '2020-01-09T11:00:00Z',
#     'v': 10206,
#     'vw': 305.486848})
# Bar({   'c': 306.3,
#     'h': 306.69,
#     'l': 305.24,
#     'n': 1794,
#     'o': 305.5,
#     't': '2020-01-09T12:00:00Z',
#     'v': 223132,
#     'vw': 306.185746})
# Bar({   'c': 306.76,
#     'h': 307.1,
#     'l': 305.54,
#     'n': 2412,
#     'o': 306,
#     't': '2020-01-09T13:00:00Z',
#     'v': 297493,
#     'vw': 306.373635})
# Bar({   'c': 308.32,
#     'h': 308.8994,
#     'l': 306.65,
#     'n': 61742,
#     'o': 306.8099,
#     't': '2020-01-09T14:00:00Z',
#     'v': 7911328,
#     'vw': 307.909244})
# Bar({   'c': 309.09,
#     'h': 309.46,
#     'l': 307.42,
#     'n': 51687,
#     'o': 308.29,
#     't': '2020-01-09T15:00:00Z',
#     'v': 5888415,
#     'vw': 308.448815})
# Bar({   'c': 309.925,
#     'h': 310.43,
#     'l': 308.98,
#     'n': 47770,
#     'o': 309.105,
#     't': '2020-01-09T16:00:00Z',
#     'v': 5796798,
#     'vw': 309.655557})
# Bar({   'c': 307.64,
#     'h': 310.03,
#     'l': 306.2,
#     'n': 53428,
#     'o': 309.9399,
#     't': '2020-01-09T17:00:00Z',
#     'v': 6725443,
#     'vw': 307.909988})
# Bar({   'c': 309.0809,
#     'h': 309.85,
#     'l': 307.43,
#     'n': 36857,
#     'o': 307.65,
#     't': '2020-01-09T18:00:00Z',
#     'v': 4739851,
#     'vw': 308.875144})
# Bar({   'c': 309.025,
#     'h': 309.49,
#     'l': 308.73,
#     'n': 24989,
#     'o': 309.075,
#     't': '2020-01-09T19:00:00Z',
#     'v': 2739861,
#     'vw': 309.092597})
# Bar({   'c': 309.71,
#     'h': 309.72,
#     'l': 308.25,
#     'n': 44835,
#     'o': 309.01,
#     't': '2020-01-09T20:00:00Z',
#     'v': 5065456,
#     'vw': 309.021813})
# Bar({   'c': 309.75,
#     'h': 309.8,
#     'l': 307.45,
#     'n': 738,
#     'o': 309.7,
#     't': '2020-01-09T21:00:00Z',
#     'v': 2933431,
#     'vw': 309.6244})
# Bar({   'c': 309.78,
#     'h': 309.79,
#     'l': 309.63,
#     'n': 294,
#     'o': 309.7,
#     't': '2020-01-09T22:00:00Z',
#     'v': 125312,
#     'vw': 309.643963})
# Bar({   'c': 310.35,
#     'h': 310.4,
#     'l': 309.79,
#     'n': 470,
#     'o': 309.79,
#     't': '2020-01-09T23:00:00Z',
#     'v': 54320,
#     'vw': 310.143694})
# Bar({   'c': 310.4,
#     'h': 310.4,
#     'l': 310.22,
#     'n': 375,
#     'o': 310.37,
#     't': '2020-01-10T00:00:00Z',
#     'v': 57616,
#     'vw': 310.357496})
# Bar({   'c': 311.88,
#     'h': 311.9,
#     'l': 311.22,
#     'n': 126,
#     'o': 311.22,
#     't': '2020-01-10T09:00:00Z',
#     'v': 12147,
#     'vw': 311.641712})
# Bar({   'c': 311.84,
#     'h': 311.97,
#     'l': 311.69,
#     'n': 81,
#     'o': 311.9,
#     't': '2020-01-10T10:00:00Z',
#     'v': 9366,
#     'vw': 311.861122})
# Bar({   'c': 311.55,
#     'h': 311.84,
#     'l': 311.49,
#     'n': 128,
#     'o': 311.77,
#     't': '2020-01-10T11:00:00Z',
#     'v': 16255,
#     'vw': 311.620603})
# Bar({   'c': 312.19,
#     'h': 312.35,
#     'l': 311.12,
#     'n': 1716,
#     'o': 311.75,
#     't': '2020-01-10T12:00:00Z',
#     'v': 180117,
#     'vw': 311.893093})
# Bar({   'c': 310.75,
#     'h': 312.34,
#     'l': 310,
#     'n': 3836,
#     'o': 312.18,
#     't': '2020-01-10T13:00:00Z',
#     'v': 466434,
#     'vw': 311.314882})
# Bar({   'c': 312.0657,
#     'h': 312.1754,
#     'l': 309.7,
#     'n': 51797,
#     'o': 310.8,
#     't': '2020-01-10T14:00:00Z',
#     'v': 6388180,
#     'vw': 310.769721})
# Bar({   'c': 312.045,
#     'h': 312.67,
#     'l': 311.67,
#     'n': 50561,
#     'o': 312.08,
#     't': '2020-01-10T15:00:00Z',
#     'v': 5813110,
#     'vw': 312.155342})
# Bar({   'c': 311.07,
#     'h': 312.33,
#     'l': 310.44,
#     'n': 39363,
#     'o': 312.05,
#     't': '2020-01-10T16:00:00Z',
#     'v': 4438616,
#     'vw': 311.372408})
# Bar({   'c': 309.77,
#     'h': 311.11,
#     'l': 308.25,
#     'n': 48663,
#     'o': 311.11,
#     't': '2020-01-10T17:00:00Z',
#     'v': 5505228,
#     'vw': 309.713165})
# Bar({   'c': 310.7,
#     'h': 310.94,
#     'l': 309.7001,
#     'n': 23807,
#     'o': 309.77,
#     't': '2020-01-10T18:00:00Z',
#     'v': 2481485,
#     'vw': 310.5202})
# Bar({   'c': 310.0652,
#     'h': 310.95,
#     'l': 309.28,
#     'n': 27016,
#     'o': 310.7,
#     't': '2020-01-10T19:00:00Z',
#     'v': 3073816,
#     'vw': 310.027004})
# Bar({   'c': 310.37,
#     'h': 310.42,
#     'l': 309.23,
#     'n': 45494,
#     'o': 310.06,
#     't': '2020-01-10T20:00:00Z',
#     'v': 5002843,
#     'vw': 309.871827})
# Bar({   'c': 310.41,
#     'h': 310.55,
#     'l': 310.21,
#     'n': 1431,
#     'o': 310.33,
#     't': '2020-01-10T21:00:00Z',
#     'v': 1746628,
#     'vw': 310.339199})
# Bar({   'c': 310.65,
#     'h': 310.69,
#     'l': 310.38,
#     'n': 200,
#     'o': 310.38,
#     't': '2020-01-10T22:00:00Z',
#     'v': 18589,
#     'vw': 310.451888})
# Bar({   'c': 310.51,
#     'h': 310.7099,
#     'l': 310.5,
#     'n': 107,
#     'o': 310.66,
#     't': '2020-01-10T23:00:00Z',
#     'v': 24647,
#     'vw': 310.55334})
# Bar({   'c': 310.67,
#     'h': 310.85,
#     'l': 310.5,
#     'n': 178,
#     'o': 310.51,
#     't': '2020-01-11T00:00:00Z',
#     'v': 33329,
#     'vw': 310.685889})
# Bar({   'c': 311.9,
#     'h': 311.95,
#     'l': 311.5,
#     'n': 79,
#     'o': 311.53,
#     't': '2020-01-13T09:00:00Z',
#     'v': 14625,
#     'vw': 311.793475})
# Bar({   'c': 312,
#     'h': 312,
#     'l': 311.65,
#     'n': 78,
#     'o': 311.9,
#     't': '2020-01-13T10:00:00Z',
#     'v': 14056,
#     'vw': 311.782269})
# Bar({   'c': 311.66,
#     'h': 312.5,
#     'l': 311.65,
#     'n': 159,
#     'o': 311.95,
#     't': '2020-01-13T11:00:00Z',
#     'v': 27356,
#     'vw': 311.944451})
# Bar({   'c': 311.55,
#     'h': 312.15,
#     'l': 311.37,
#     'n': 680,
#     'o': 311.7,
#     't': '2020-01-13T12:00:00Z',
#     'v': 83705,
#     'vw': 311.74709})
# Bar({   'c': 311.4115,
#     'h': 312.191,
#     'l': 311.4,
#     'n': 1556,
#     'o': 311.95,
#     't': '2020-01-13T13:00:00Z',
#     'v': 176063,
#     'vw': 311.672923})
# Bar({   'c': 312.92,
#     'h': 313.38,
#     'l': 311.35,
#     'n': 44686,
#     'o': 311.41,
#     't': '2020-01-13T14:00:00Z',
#     'v': 5458817,
#     'vw': 312.522544})
# Bar({   'c': 312.083,
#     'h': 313.03,
#     'l': 311.15,
#     'n': 42788,
#     'o': 312.97,
#     't': '2020-01-13T15:00:00Z',
#     'v': 4622713,
#     'vw': 311.978722})
# Bar({   'c': 312.792,
#     'h': 313.36,
#     'l': 311.4,
#     'n': 33055,
#     'o': 312.09,
#     't': '2020-01-13T16:00:00Z',
#     'v': 3540994,
#     'vw': 312.197818})
# Bar({   'c': 313.13,
#     'h': 313.32,
#     'l': 312.45,
#     'n': 25238,
#     'o': 312.79,
#     't': '2020-01-13T17:00:00Z',
#     'v': 2693011,
#     'vw': 312.88806})
# Bar({   'c': 313.62,
#     'h': 313.79,
#     'l': 312.86,
#     'n': 21695,
#     'o': 313.13,
#     't': '2020-01-13T18:00:00Z',
#     'v': 2318733,
#     'vw': 313.432528})
# Bar({   'c': 314.93,
#     'h': 314.98,
#     'l': 313.31,
#     'n': 30387,
#     'o': 313.5625,
#     't': '2020-01-13T19:00:00Z',
#     'v': 3475629,
#     'vw': 314.359758})
# Bar({   'c': 316.97,
#     'h': 317.07,
#     'l': 314.63,
#     'n': 50194,
#     'o': 314.93,
#     't': '2020-01-13T20:00:00Z',
#     'v': 5680697,
#     'vw': 315.850601})
# Bar({   'c': 317.26,
#     'h': 317.49,
#     'l': 316.95,
#     'n': 2260,
#     'o': 316.96,
#     't': '2020-01-13T21:00:00Z',
#     'v': 2213329,
#     'vw': 316.970258})
# Bar({   'c': 317.54,
#     'h': 317.59,
#     'l': 316.96,
#     'n': 589,
#     'o': 317.25,
#     't': '2020-01-13T22:00:00Z',
#     'v': 49799,
#     'vw': 317.346284})
# Bar({   'c': 318,
#     'h': 318.23,
#     'l': 317.5,
#     'n': 446,
#     'o': 317.5,
#     't': '2020-01-13T23:00:00Z',
#     'v': 45876,
#     'vw': 317.786569})
# Bar({   'c': 318.78,
#     'h': 318.8,
#     'l': 318.03,
#     'n': 665,
#     'o': 318.15,
#     't': '2020-01-14T00:00:00Z',
#     'v': 98784,
#     'vw': 318.401794})
# Bar({   'c': 316.5,
#     'h': 316.73,
#     'l': 315.72,
#     'n': 380,
#     'o': 316.5,
#     't': '2020-01-14T09:00:00Z',
#     'v': 46063,
#     'vw': 316.359837})
# Bar({   'c': 316.02,
#     'h': 316.7,
#     'l': 316.01,
#     'n': 160,
#     'o': 316.35,
#     't': '2020-01-14T10:00:00Z',
#     'v': 19789,
#     'vw': 316.318767})
# Bar({   'c': 316.32,
#     'h': 316.49,
#     'l': 315.65,
#     'n': 208,
#     'o': 316.38,
#     't': '2020-01-14T11:00:00Z',
#     'v': 24748,
#     'vw': 316.071697})
# Bar({   'c': 317.25,
#     'h': 317.77,
#     'l': 316.21,
#     'n': 1380,
#     'o': 316.48,
#     't': '2020-01-14T12:00:00Z',
#     'v': 179040,
#     'vw': 317.182822})
# Bar({   'c': 316.84,
#     'h': 317.77,
#     'l': 316.43,
#     'n': 2732,
#     'o': 317.02,
#     't': '2020-01-14T13:00:00Z',
#     'v': 361942,
#     'vw': 317.009368})
# Bar({   'c': 313.7701,
#     'h': 317.24,
#     'l': 313.3506,
#     'n': 58867,
#     'o': 316.8,
#     't': '2020-01-14T14:00:00Z',
#     'v': 6830676,
#     'vw': 315.81182})
# Bar({   'c': 315.7533,
#     'h': 317.57,
#     'l': 313.47,
#     'n': 67206,
#     'o': 313.79,
#     't': '2020-01-14T15:00:00Z',
#     'v': 7588191,
#     'vw': 315.952142})
# Bar({   'c': 316.54,
#     'h': 316.6,
#     'l': 314.6,
#     'n': 34063,
#     'o': 315.76,
#     't': '2020-01-14T16:00:00Z',
#     'v': 3729013,
#     'vw': 315.545383})
# Bar({   'c': 314.7201,
#     'h': 316.68,
#     'l': 314.6,
#     'n': 31182,
#     'o': 316.53,
#     't': '2020-01-14T17:00:00Z',
#     'v': 3518831,
#     'vw': 315.50876})
# Bar({   'c': 313.39,
#     'h': 315.87,
#     'l': 312.75,
#     'n': 47237,
#     'o': 314.73,
#     't': '2020-01-14T18:00:00Z',
#     'v': 5227349,
#     'vw': 314.472214})
# Bar({   'c': 313.5038,
#     'h': 315,
#     'l': 312.17,
#     'n': 44189,
#     'o': 313.3799,
#     't': '2020-01-14T19:00:00Z',
#     'v': 5032915,
#     'vw': 313.481093})
# Bar({   'c': 312.69,
#     'h': 314.2,
#     'l': 312.22,
#     'n': 50501,
#     'o': 313.54,
#     't': '2020-01-14T20:00:00Z',
#     'v': 5005603,
#     'vw': 313.091397})
# Bar({   'c': 312.97,
#     'h': 315.785,
#     'l': 312.45,
#     'n': 1776,
#     'o': 312.68,
#     't': '2020-01-14T21:00:00Z',
#     'v': 2494333,
#     'vw': 312.695817})
# Bar({   'c': 312.75,
#     'h': 313.2,
#     'l': 312.67,
#     'n': 600,
#     'o': 313,
#     't': '2020-01-14T22:00:00Z',
#     'v': 389729,
#     'vw': 312.704807})
# Bar({   'c': 310.98,
#     'h': 312.77,
#     'l': 310.98,
#     'n': 1243,
#     'o': 312.74,
#     't': '2020-01-14T23:00:00Z',
#     'v': 128013,
#     'vw': 311.988761})
# Bar({   'c': 311.75,
#     'h': 311.98,
#     'l': 310.79,
#     'n': 723,
#     'o': 310.98,
#     't': '2020-01-15T00:00:00Z',
#     'v': 67813,
#     'vw': 311.425784})
# Bar({   'c': 311.56,
#     'h': 311.98,
#     'l': 310.88,
#     'n': 159,
#     'o': 311.89,
#     't': '2020-01-15T09:00:00Z',
#     'v': 18244,
#     'vw': 311.360576})
# Bar({   'c': 311.89,
#     'h': 311.98,
#     'l': 311.2,
#     'n': 56,
#     'o': 311.51,
#     't': '2020-01-15T10:00:00Z',
#     'v': 11956,
#     'vw': 311.685275})
# Bar({   'c': 311.95,
#     'h': 311.95,
#     'l': 311.67,
#     'n': 37,
#     'o': 311.89,
#     't': '2020-01-15T11:00:00Z',
#     'v': 3934,
#     'vw': 311.855592})
# Bar({   'c': 313.11,
#     'h': 313.3,
#     'l': 311.5,
#     'n': 758,
#     'o': 311.9,
#     't': '2020-01-15T12:00:00Z',
#     'v': 86019,
#     'vw': 312.494984})
# Bar({   'c': 312.1,
#     'h': 313.39,
#     'l': 311.67,
#     'n': 2140,
#     'o': 313.14,
#     't': '2020-01-15T13:00:00Z',
#     'v': 242783,
#     'vw': 312.695427})
# Bar({   'c': 315.35,
#     'h': 315.43,
#     'l': 311.46,
#     'n': 44968,
#     'o': 312,
#     't': '2020-01-15T14:00:00Z',
#     'v': 5395073,
#     'vw': 313.684512})
# Bar({   'c': 314.5,
#     'h': 315.5,
#     'l': 313.81,
#     'n': 39576,
#     'o': 315.357,
#     't': '2020-01-15T15:00:00Z',
#     'v': 4349216,
#     'vw': 314.60176})
# Bar({   'c': 313.95,
#     'h': 314.67,
#     'l': 313.38,
#     'n': 28686,
#     'o': 314.4923,
#     't': '2020-01-15T16:00:00Z',
#     'v': 3041831,
#     'vw': 314.044938})
# Bar({   'c': 313.91,
#     'h': 314.6,
#     'l': 313.69,
#     'n': 21635,
#     'o': 313.92,
#     't': '2020-01-15T17:00:00Z',
#     'v': 2149581,
#     'vw': 314.145032})
# Bar({   'c': 312.66,
#     'h': 314.44,
#     'l': 312.16,
#     'n': 29038,
#     'o': 313.9,
#     't': '2020-01-15T18:00:00Z',
#     'v': 3031607,
#     'vw': 313.519606})
# Bar({   'c': 312.96,
#     'h': 313.83,
#     'l': 312.5,
#     'n': 23161,
#     'o': 312.67,
#     't': '2020-01-15T19:00:00Z',
#     'v': 2439321,
#     'vw': 313.231757})
# Bar({   'c': 311.5,
#     'h': 313.01,
#     'l': 309.55,
#     'n': 71752,
#     'o': 312.98,
#     't': '2020-01-15T20:00:00Z',
#     'v': 7476339,
#     'vw': 310.976364})
# Bar({   'c': 311.35,
#     'h': 311.65,
#     'l': 311.15,
#     'n': 1352,
#     'o': 311.5,
#     't': '2020-01-15T21:00:00Z',
#     'v': 1879445,
#     'vw': 311.342053})
# Bar({   'c': 311.45,
#     'h': 311.61,
#     'l': 311.34,
#     'n': 416,
#     'o': 311.35,
#     't': '2020-01-15T22:00:00Z',
#     'v': 108848,
#     'vw': 311.393006})
# Bar({   'c': 312.07,
#     'h': 312.25,
#     'l': 311.48,
#     'n': 433,
#     'o': 311.48,
#     't': '2020-01-15T23:00:00Z',
#     'v': 43056,
#     'vw': 312.06})
# Bar({   'c': 312.2,
#     'h': 312.29,
#     'l': 312,
#     'n': 269,
#     'o': 312.29,
#     't': '2020-01-16T00:00:00Z',
#     'v': 32856,
#     'vw': 312.112177})
# Bar({   'c': 313.8,
#     'h': 314.1,
#     'l': 313.05,
#     'n': 77,
#     'o': 313.05,
#     't': '2020-01-16T09:00:00Z',
#     'v': 8874,
#     'vw': 313.778083})
# Bar({   'c': 313.7,
#     'h': 313.78,
#     'l': 313.51,
#     'n': 45,
#     'o': 313.6,
#     't': '2020-01-16T10:00:00Z',
#     'v': 6888,
#     'vw': 313.649457})
# Bar({   'c': 313.7,
#     'h': 313.83,
#     'l': 313.28,
#     'n': 72,
#     'o': 313.71,
#     't': '2020-01-16T11:00:00Z',
#     'v': 6140,
#     'vw': 313.664559})
# Bar({   'c': 313.61,
#     'h': 314.49,
#     'l': 313.6,
#     'n': 1172,
#     'o': 313.63,
#     't': '2020-01-16T12:00:00Z',
#     'v': 141576,
#     'vw': 314.025219})
# Bar({   'c': 314.05,
#     'h': 314.37,
#     'l': 313.5,
#     'n': 1390,
#     'o': 313.8,
#     't': '2020-01-16T13:00:00Z',
#     'v': 145198,
#     'vw': 313.93169})
# Bar({   'c': 314.569,
#     'h': 315.27,
#     'l': 313.5,
#     'n': 36872,
#     'o': 313.95,
#     't': '2020-01-16T14:00:00Z',
#     'v': 4819441,
#     'vw': 314.48008})
# Bar({   'c': 312.8,
#     'h': 315.7,
#     'l': 312.7,
#     'n': 46505,
#     'o': 314.55,
#     't': '2020-01-16T15:00:00Z',
#     'v': 5256939,
#     'vw': 314.462748})
# Bar({   'c': 313.31,
#     'h': 313.82,
#     'l': 312.09,
#     'n': 31501,
#     'o': 312.86,
#     't': '2020-01-16T16:00:00Z',
#     'v': 3586182,
#     'vw': 312.965114})
# Bar({   'c': 312.8401,
#     'h': 313.47,
#     'l': 312.45,
#     'n': 17161,
#     'o': 313.293,
#     't': '2020-01-16T17:00:00Z',
#     'v': 1745832,
#     'vw': 312.891687})
# Bar({   'c': 313.7,
#     'h': 313.88,
#     'l': 312.66,
#     'n': 16542,
#     'o': 312.86,
#     't': '2020-01-16T18:00:00Z',
#     'v': 1583361,
#     'vw': 313.303783})
# Bar({   'c': 313.86,
#     'h': 314.3237,
#     'l': 313.52,
#     'n': 18759,
#     'o': 313.69,
#     't': '2020-01-16T19:00:00Z',
#     'v': 1906548,
#     'vw': 313.936912})
# Bar({   'c': 315.37,
#     'h': 315.37,
#     'l': 313.6,
#     'n': 35089,
#     'o': 313.88,
#     't': '2020-01-16T20:00:00Z',
#     'v': 4892175,
#     'vw': 314.521649})
# Bar({   'c': 315.1,
#     'h': 315.28,
#     'l': 314.91,
#     'n': 1152,
#     'o': 315.24,
#     't': '2020-01-16T21:00:00Z',
#     'v': 2737814,
#     'vw': 315.23573})
# Bar({   'c': 315.07,
#     'h': 315.24,
#     'l': 314.95,
#     'n': 226,
#     'o': 315.15,
#     't': '2020-01-16T22:00:00Z',
#     'v': 727797,
#     'vw': 315.235489})
# Bar({   'c': 315.3,
#     'h': 315.49,
#     'l': 315,
#     'n': 221,
#     'o': 315,
#     't': '2020-01-16T23:00:00Z',
#     'v': 38944,
#     'vw': 315.318034})
# Bar({   'c': 315.29,
#     'h': 315.39,
#     'l': 315.2,
#     'n': 175,
#     'o': 315.25,
#     't': '2020-01-17T00:00:00Z',
#     'v': 21866,
#     'vw': 315.308366})
# Bar({   'c': 316.99,
#     'h': 317.2,
#     'l': 316.04,
#     'n': 81,
#     'o': 316.04,
#     't': '2020-01-17T09:00:00Z',
#     'v': 10782,
#     'vw': 316.828845})
# Bar({   'c': 317.02,
#     'h': 317.35,
#     'l': 317.02,
#     'n': 68,
#     'o': 317.13,
#     't': '2020-01-17T10:00:00Z',
#     'v': 12393,
#     'vw': 317.22952})
# Bar({   'c': 317.15,
#     'h': 317.2,
#     'l': 316.97,
#     'n': 75,
#     'o': 317.01,
#     't': '2020-01-17T11:00:00Z',
#     'v': 10676,
#     'vw': 317.02649})
# Bar({   'c': 316.62,
#     'h': 317.24,
#     'l': 316.01,
#     'n': 727,
#     'o': 317.01,
#     't': '2020-01-17T12:00:00Z',
#     'v': 99723,
#     'vw': 316.788772})
# Bar({   'c': 316.7301,
#     'h': 317.18,
#     'l': 315.97,
#     'n': 2410,
#     'o': 317.0998,
#     't': '2020-01-17T13:00:00Z',
#     'v': 317059,
#     'vw': 316.608798})
# Bar({   'c': 316.935,
#     'h': 317.05,
#     'l': 315.24,
#     'n': 39231,
#     'o': 316.7,
#     't': '2020-01-17T14:00:00Z',
#     'v': 6549600,
#     'vw': 316.264831})
# Bar({   'c': 316.2804,
#     'h': 317.25,
#     'l': 315.91,
#     'n': 40623,
#     'o': 316.88,
#     't': '2020-01-17T15:00:00Z',
#     'v': 4386870,
#     'vw': 316.53986})
# Bar({   'c': 316.36,
#     'h': 316.4,
#     'l': 315,
#     'n': 29672,
#     'o': 316.3,
#     't': '2020-01-17T16:00:00Z',
#     'v': 3171385,
#     'vw': 315.789516})
# Bar({   'c': 315.8199,
#     'h': 316.9299,
#     'l': 315.75,
#     'n': 23058,
#     'o': 316.365,
#     't': '2020-01-17T17:00:00Z',
#     'v': 2567355,
#     'vw': 316.49692})
# Bar({   'c': 316.77,
#     'h': 316.83,
#     'l': 315.39,
#     'n': 21667,
#     'o': 315.82,
#     't': '2020-01-17T18:00:00Z',
#     'v': 2352314,
#     'vw': 316.187706})
# Bar({   'c': 317.07,
#     'h': 317.07,
#     'l': 316.42,
#     'n': 24188,
#     'o': 316.775,
#     't': '2020-01-17T19:00:00Z',
#     'v': 3523502,
#     'vw': 316.714017})
# Bar({   'c': 318.67,
#     'h': 318.74,
#     'l': 316.62,
#     'n': 54251,
#     'o': 317.07,
#     't': '2020-01-17T20:00:00Z',
#     'v': 6356611,
#     'vw': 317.73335})
# Bar({   'c': 318.65,
#     'h': 318.78,
#     'l': 318.41,
#     'n': 1593,
#     'o': 318.67,
#     't': '2020-01-17T21:00:00Z',
#     'v': 4455691,
#     'vw': 318.725781})
# Bar({   'c': 318.64,
#     'h': 318.73,
#     'l': 318.51,
#     'n': 303,
#     'o': 318.56,
#     't': '2020-01-17T22:00:00Z',
#     'v': 311629,
#     'vw': 318.723867})
# Bar({   'c': 318.67,
#     'h': 318.72,
#     'l': 318.61,
#     'n': 121,
#     'o': 318.65,
#     't': '2020-01-17T23:00:00Z',
#     'v': 16420,
#     'vw': 318.678428})
# Bar({   'c': 318.65,
#     'h': 318.73,
#     'l': 318.6,
#     'n': 167,
#     'o': 318.7,
#     't': '2020-01-18T00:00:00Z',
#     'v': 23384,
#     'vw': 318.671572})
# Bar({   'c': 316.9,
#     'h': 317.24,
#     'l': 316.34,
#     'n': 113,
#     'o': 316.97,
#     't': '2020-01-21T09:00:00Z',
#     'v': 8679,
#     'vw': 316.791477})
# Bar({   'c': 316.63,
#     'h': 317,
#     'l': 316.5,
#     'n': 50,
#     'o': 316.8,
#     't': '2020-01-21T10:00:00Z',
#     'v': 6962,
#     'vw': 316.753442})
# Bar({   'c': 317,
#     'h': 317.14,
#     'l': 316.41,
#     'n': 98,
#     'o': 317,
#     't': '2020-01-21T11:00:00Z',
#     'v': 8224,
#     'vw': 316.674729})
# Bar({   'c': 317,
#     'h': 317.49,
#     'l': 316.81,
#     'n': 709,
#     'o': 316.99,
#     't': '2020-01-21T12:00:00Z',
#     'v': 83204,
#     'vw': 317.087703})
# Bar({   'c': 316.8,
#     'h': 317.36,
#     'l': 316.78,
#     'n': 1448,
#     'o': 317.25,
#     't': '2020-01-21T13:00:00Z',
#     'v': 134314,
#     'vw': 316.983959})
# Bar({   'c': 318.19,
#     'h': 318.86,
#     'l': 316.65,
#     'n': 36540,
#     'o': 316.82,
#     't': '2020-01-21T14:00:00Z',
#     'v': 4398873,
#     'vw': 317.7952})
# Bar({   'c': 317.38,
#     'h': 319.02,
#     'l': 317.09,
#     'n': 37739,
#     'o': 318.23,
#     't': '2020-01-21T15:00:00Z',
#     'v': 4109867,
#     'vw': 317.913409})
# Bar({   'c': 318.46,
#     'h': 319,
#     'l': 317.28,
#     'n': 24267,
#     'o': 317.37,
#     't': '2020-01-21T16:00:00Z',
#     'v': 2549428,
#     'vw': 318.335264})
# Bar({   'c': 317.96,
#     'h': 318.5032,
#     'l': 317.8,
#     'n': 19386,
#     'o': 318.468,
#     't': '2020-01-21T17:00:00Z',
#     'v': 1990788,
#     'vw': 318.121941})
# Bar({   'c': 316.56,
#     'h': 318.2,
#     'l': 316.34,
#     'n': 26893,
#     'o': 317.99,
#     't': '2020-01-21T18:00:00Z',
#     'v': 3031204,
#     'vw': 317.301748})
# Bar({   'c': 316.8907,
#     'h': 317.27,
#     'l': 316.2571,
#     'n': 23034,
#     'o': 316.5662,
#     't': '2020-01-21T19:00:00Z',
#     'v': 2406154,
#     'vw': 316.692566})
# Bar({   'c': 316.55,
#     'h': 317.23,
#     'l': 316,
#     'n': 35668,
#     'o': 316.89,
#     't': '2020-01-21T20:00:00Z',
#     'v': 3509170,
#     'vw': 316.662707})
# Bar({   'c': 316.6,
#     'h': 317.452,
#     'l': 316.24,
#     'n': 1717,
#     'o': 316.57,
#     't': '2020-01-21T21:00:00Z',
#     'v': 5351421,
#     'vw': 316.572518})
# Bar({   'c': 316.5,
#     'h': 316.7,
#     'l': 316.5,
#     'n': 321,
#     'o': 316.5701,
#     't': '2020-01-21T22:00:00Z',
#     'v': 25743,
#     'vw': 316.645849})
# Bar({   'c': 317.15,
#     'h': 317.23,
#     'l': 316.53,
#     'n': 143,
#     'o': 316.65,
#     't': '2020-01-21T23:00:00Z',
#     'v': 16849,
#     'vw': 316.850419})
# Bar({   'c': 317.23,
#     'h': 317.4,
#     'l': 317,
#     'n': 212,
#     'o': 317.15,
#     't': '2020-01-22T00:00:00Z',
#     'v': 29086,
#     'vw': 317.214665})
# Bar({   'c': 318.5,
#     'h': 318.5,
#     'l': 318.07,
#     'n': 77,
#     'o': 318.07,
#     't': '2020-01-22T09:00:00Z',
#     'v': 8358,
#     'vw': 318.401653})
# Bar({   'c': 318.68,
#     'h': 318.75,
#     'l': 318.5,
#     'n': 24,
#     'o': 318.75,
#     't': '2020-01-22T10:00:00Z',
#     'v': 2931,
#     'vw': 318.676513})
# Bar({   'c': 319.17,
#     'h': 319.17,
#     'l': 318.67,
#     'n': 118,
#     'o': 318.68,
#     't': '2020-01-22T11:00:00Z',
#     'v': 18160,
#     'vw': 318.943127})
# Bar({   'c': 319.1,
#     'h': 319.43,
#     'l': 319,
#     'n': 794,
#     'o': 319.1,
#     't': '2020-01-22T12:00:00Z',
#     'v': 104611,
#     'vw': 319.121204})
# Bar({   'c': 318.62,
#     'h': 319.4,
#     'l': 317.36,
#     'n': 1316,
#     'o': 319.05,
#     't': '2020-01-22T13:00:00Z',
#     'v': 143295,
#     'vw': 318.972046})
# Bar({   'c': 318.06,
#     'h': 318.94,
#     'l': 317.31,
#     'n': 29772,
#     'o': 318.62,
#     't': '2020-01-22T14:00:00Z',
#     'v': 3557908,
#     'vw': 318.076061})
# Bar({   'c': 317.8839,
#     'h': 318.9,
#     'l': 317.52,
#     'n': 34643,
#     'o': 318.1,
#     't': '2020-01-22T15:00:00Z',
#     'v': 3751929,
#     'vw': 318.246655})
# Bar({   'c': 318.52,
#     'h': 318.685,
#     'l': 317.46,
#     'n': 25422,
#     'o': 317.89,
#     't': '2020-01-22T16:00:00Z',
#     'v': 2588683,
#     'vw': 318.126249})
# Bar({   'c': 319.63,
#     'h': 319.75,
#     'l': 318.1,
#     'n': 25286,
#     'o': 318.52,
#     't': '2020-01-22T17:00:00Z',
#     'v': 2940587,
#     'vw': 318.945647})
# Bar({   'c': 319.0721,
#     'h': 319.89,
#     'l': 319.05,
#     'n': 19810,
#     'o': 319.64,
#     't': '2020-01-22T18:00:00Z',
#     'v': 2029673,
#     'vw': 319.544352})
# Bar({   'c': 319.88,
#     'h': 319.99,
#     'l': 319,
#     'n': 20548,
#     'o': 319.09,
#     't': '2020-01-22T19:00:00Z',
#     'v': 2118232,
#     'vw': 319.486535})
# Bar({   'c': 317.7,
#     'h': 319.9,
#     'l': 317.57,
#     'n': 48273,
#     'o': 319.9,
#     't': '2020-01-22T20:00:00Z',
#     'v': 5286009,
#     'vw': 318.456358})
# Bar({   'c': 317.4,
#     'h': 317.82,
#     'l': 317.2,
#     'n': 1088,
#     'o': 317.7,
#     't': '2020-01-22T21:00:00Z',
#     'v': 2808865,
#     'vw': 317.699851})
# Bar({   'c': 317.48,
#     'h': 317.65,
#     'l': 317.39,
#     'n': 155,
#     'o': 317.39,
#     't': '2020-01-22T22:00:00Z',
#     'v': 10369,
#     'vw': 317.51308})
# Bar({   'c': 317.5,
#     'h': 317.62,
#     'l': 317.15,
#     'n': 208,
#     'o': 317.5,
#     't': '2020-01-22T23:00:00Z',
#     'v': 37603,
#     'vw': 317.453283})
# Bar({   'c': 317.5,
#     'h': 317.8,
#     'l': 317.35,
#     'n': 220,
#     'o': 317.42,
#     't': '2020-01-23T00:00:00Z',
#     'v': 33143,
#     'vw': 317.595075})
# Bar({   'c': 317.11,
#     'h': 317.52,
#     'l': 317,
#     'n': 22,
#     'o': 317,
#     't': '2020-01-23T09:00:00Z',
#     'v': 2816,
#     'vw': 317.26859})
# Bar({   'c': 317.82,
#     'h': 318,
#     'l': 317.15,
#     'n': 30,
#     'o': 317.15,
#     't': '2020-01-23T10:00:00Z',
#     'v': 2360,
#     'vw': 317.747382})
# Bar({   'c': 317.7,
#     'h': 318.14,
#     'l': 317.7,
#     'n': 40,
#     'o': 318,
#     't': '2020-01-23T11:00:00Z',
#     'v': 6508,
#     'vw': 317.984335})
# Bar({   'c': 317.41,
#     'h': 318.25,
#     'l': 317.34,
#     'n': 430,
#     'o': 318,
#     't': '2020-01-23T12:00:00Z',
#     'v': 53864,
#     'vw': 317.727629})
# Bar({   'c': 317.26,
#     'h': 318.33,
#     'l': 317.1,
#     'n': 1040,
#     'o': 318.2994,
#     't': '2020-01-23T13:00:00Z',
#     'v': 127575,
#     'vw': 317.485742})
# Bar({   'c': 317.13,
#     'h': 318.49,
#     'l': 315.65,
#     'n': 38345,
#     'o': 317.27,
#     't': '2020-01-23T14:00:00Z',
#     'v': 3943335,
#     'vw': 316.987774})
# Bar({   'c': 317.33,
#     'h': 318.12,
#     'l': 316.29,
#     'n': 36256,
#     'o': 317.07,
#     't': '2020-01-23T15:00:00Z',
#     'v': 3803398,
#     'vw': 317.281176})
# Bar({   'c': 317.51,
#     'h': 317.91,
#     'l': 316.91,
#     'n': 24362,
#     'o': 317.35,
#     't': '2020-01-23T16:00:00Z',
#     'v': 2541583,
#     'vw': 317.413043})
# Bar({   'c': 317.715,
#     'h': 318.195,
#     'l': 317.2772,
#     'n': 16631,
#     'o': 317.5,
#     't': '2020-01-23T17:00:00Z',
#     'v': 1407594,
#     'vw': 317.840267})
# Bar({   'c': 318.74,
#     'h': 318.89,
#     'l': 317.4,
#     'n': 20286,
#     'o': 317.7,
#     't': '2020-01-23T18:00:00Z',
#     'v': 2287082,
#     'vw': 318.152333})
# Bar({   'c': 319.2399,
#     'h': 319.25,
#     'l': 318.539,
#     'n': 21326,
#     'o': 318.73,
#     't': '2020-01-23T19:00:00Z',
#     'v': 2504352,
#     'vw': 318.896189})
# Bar({   'c': 319.2899,
#     'h': 319.56,
#     'l': 318.6,
#     'n': 36016,
#     'o': 319.2207,
#     't': '2020-01-23T20:00:00Z',
#     'v': 4017744,
#     'vw': 319.171763})
# Bar({   'c': 319.38,
#     'h': 319.6,
#     'l': 319.23,
#     'n': 1204,
#     'o': 319.23,
#     't': '2020-01-23T21:00:00Z',
#     'v': 5327218,
#     'vw': 319.230923})
# Bar({   'c': 319.54,
#     'h': 319.59,
#     'l': 319.34,
#     'n': 248,
#     'o': 319.38,
#     't': '2020-01-23T22:00:00Z',
#     'v': 22221,
#     'vw': 319.467404})
# Bar({   'c': 319.65,
#     'h': 319.75,
#     'l': 319.45,
#     'n': 256,
#     'o': 319.5,
#     't': '2020-01-23T23:00:00Z',
#     'v': 40614,
#     'vw': 319.593795})
# Bar({   'c': 319.58,
#     'h': 319.75,
#     'l': 319.55,
#     'n': 163,
#     'o': 319.7,
#     't': '2020-01-24T00:00:00Z',
#     'v': 20881,
#     'vw': 319.687768})
# Bar({   'c': 320.49,
#     'h': 320.66,
#     'l': 320.33,
#     'n': 43,
#     'o': 320.33,
#     't': '2020-01-24T09:00:00Z',
#     'v': 3671,
#     'vw': 320.545764})
# Bar({   'c': 320.16,
#     'h': 320.4,
#     'l': 320.16,
#     'n': 42,
#     'o': 320.39,
#     't': '2020-01-24T10:00:00Z',
#     'v': 5830,
#     'vw': 320.23457})
# Bar({   'c': 320.3,
#     'h': 320.38,
#     'l': 320.1,
#     'n': 66,
#     'o': 320.38,
#     't': '2020-01-24T11:00:00Z',
#     'v': 8035,
#     'vw': 320.232332})
# Bar({   'c': 319.82,
#     'h': 320.3,
#     'l': 319.7,
#     'n': 600,
#     'o': 320.3,
#     't': '2020-01-24T12:00:00Z',
#     'v': 84810,
#     'vw': 319.92877})
# Bar({   'c': 320.22,
#     'h': 320.3,
#     'l': 319.72,
#     'n': 1544,
#     'o': 319.78,
#     't': '2020-01-24T13:00:00Z',
#     'v': 204431,
#     'vw': 320.021365})
# Bar({   'c': 322.61,
#     'h': 322.63,
#     'l': 319.8601,
#     'n': 40450,
#     'o': 320.22,
#     't': '2020-01-24T14:00:00Z',
#     'v': 5454267,
#     'vw': 321.122746})
# Bar({   'c': 322.22,
#     'h': 322.63,
#     'l': 321,
#     'n': 42883,
#     'o': 322.62,
#     't': '2020-01-24T15:00:00Z',
#     'v': 4849214,
#     'vw': 321.822207})
# Bar({   'c': 321.97,
#     'h': 323.33,
#     'l': 321.75,
#     'n': 38974,
#     'o': 322.2687,
#     't': '2020-01-24T16:00:00Z',
#     'v': 4244231,
#     'vw': 322.505898})
# Bar({   'c': 321.1022,
#     'h': 321.985,
#     'l': 319.31,
#     'n': 46621,
#     'o': 321.95,
#     't': '2020-01-24T17:00:00Z',
#     'v': 5423123,
#     'vw': 320.76631})
# Bar({   'c': 319.85,
#     'h': 321.15,
#     'l': 319.05,
#     'n': 28103,
#     'o': 321.13,
#     't': '2020-01-24T18:00:00Z',
#     'v': 3131472,
#     'vw': 320.078896})
# Bar({   'c': 320.1784,
#     'h': 320.26,
#     'l': 317.89,
#     'n': 42306,
#     'o': 319.87,
#     't': '2020-01-24T19:00:00Z',
#     'v': 4827796,
#     'vw': 319.136854})
# Bar({   'c': 318.33,
#     'h': 320.38,
#     'l': 317.5188,
#     'n': 52235,
#     'o': 320.16,
#     't': '2020-01-24T20:00:00Z',
#     'v': 5751545,
#     'vw': 318.882772})
# Bar({   'c': 318.21,
#     'h': 320.54,
#     'l': 318.2,
#     'n': 747,
#     'o': 318.25,
#     't': '2020-01-24T21:00:00Z',
#     'v': 2550007,
#     'vw': 318.317187})
# Bar({   'c': 318,
#     'h': 318.3499,
#     'l': 317.83,
#     'n': 467,
#     'o': 318.3499,
#     't': '2020-01-24T22:00:00Z',
#     'v': 47441,
#     'vw': 318.069768})
# Bar({   'c': 317.75,
#     'h': 318.1,
#     'l': 317.75,
#     'n': 161,
#     'o': 317.92,
#     't': '2020-01-24T23:00:00Z',
#     'v': 15123,
#     'vw': 317.894526})
# Bar({   'c': 317.58,
#     'h': 317.99,
#     'l': 317.51,
#     'n': 214,
#     'o': 317.85,
#     't': '2020-01-25T00:00:00Z',
#     'v': 22641,
#     'vw': 317.718749})
# Bar({   'c': 312.09,
#     'h': 313.9,
#     'l': 311.59,
#     'n': 519,
#     'o': 313.9,
#     't': '2020-01-27T09:00:00Z',
#     'v': 54793,
#     'vw': 312.65838})
# Bar({   'c': 309.5,
#     'h': 312.1,
#     'l': 309.5,
#     'n': 580,
#     'o': 312.09,
#     't': '2020-01-27T10:00:00Z',
#     'v': 68474,
#     'vw': 310.524638})
# Bar({   'c': 310.3,
#     'h': 310.75,
#     'l': 308.59,
#     'n': 875,
#     'o': 309.27,
#     't': '2020-01-27T11:00:00Z',
#     'v': 98172,
#     'vw': 309.58164})
# Bar({   'c': 311.25,
#     'h': 312.39,
#     'l': 310.15,
#     'n': 2304,
#     'o': 310.55,
#     't': '2020-01-27T12:00:00Z',
#     'v': 215329,
#     'vw': 311.553219})
# Bar({   'c': 311.2499,
#     'h': 312.4,
#     'l': 310.62,
#     'n': 4215,
#     'o': 311.2,
#     't': '2020-01-27T13:00:00Z',
#     'v': 390345,
#     'vw': 311.475612})
# Bar({   'c': 311.43,
#     'h': 311.77,
#     'l': 305.89,
#     'n': 97577,
#     'o': 311.22,
#     't': '2020-01-27T14:00:00Z',
#     'v': 10329066,
#     'vw': 309.359761})
# Bar({   'c': 309.44,
#     'h': 311.7599,
#     'l': 308.86,
#     'n': 67512,
#     'o': 311.51,
#     't': '2020-01-27T15:00:00Z',
#     'v': 6430018,
#     'vw': 310.419665})
# Bar({   'c': 309.3999,
#     'h': 310.0499,
#     'l': 307.53,
#     'n': 49905,
#     'o': 309.42,
#     't': '2020-01-27T16:00:00Z',
#     'v': 4758541,
#     'vw': 308.816146})
# Bar({   'c': 311.18,
#     'h': 311.59,
#     'l': 308.79,
#     'n': 36104,
#     'o': 309.38,
#     't': '2020-01-27T17:00:00Z',
#     'v': 3430904,
#     'vw': 310.62256})
# Bar({   'c': 310.2782,
#     'h': 311.6,
#     'l': 310.1,
#     'n': 27056,
#     'o': 311.18,
#     't': '2020-01-27T18:00:00Z',
#     'v': 2302109,
#     'vw': 310.906373})
# Bar({   'c': 309.516,
#     'h': 311.2,
#     'l': 308.92,
#     'n': 34412,
#     'o': 310.2999,
#     't': '2020-01-27T19:00:00Z',
#     'v': 3010453,
#     'vw': 310.261777})
# Bar({   'c': 308.95,
#     'h': 309.82,
#     'l': 304.88,
#     'n': 55150,
#     'o': 309.49,
#     't': '2020-01-27T20:00:00Z',
#     'v': 5337122,
#     'vw': 309.116572})
# Bar({   'c': 308.72,
#     'h': 309.25,
#     'l': 308.55,
#     'n': 1875,
#     'o': 308.95,
#     't': '2020-01-27T21:00:00Z',
#     'v': 3527231,
#     'vw': 308.948108})
# Bar({   'c': 309.0999,
#     'h': 310.06,
#     'l': 308.25,
#     'n': 685,
#     'o': 308.71,
#     't': '2020-01-27T22:00:00Z',
#     'v': 402682,
#     'vw': 308.948634})
# Bar({   'c': 309.77,
#     'h': 310.12,
#     'l': 309,
#     'n': 553,
#     'o': 309,
#     't': '2020-01-27T23:00:00Z',
#     'v': 67880,
#     'vw': 309.706204})
# Bar({   'c': 309.25,
#     'h': 310,
#     'l': 309.1,
#     'n': 502,
#     'o': 309.8,
#     't': '2020-01-28T00:00:00Z',
#     'v': 54506,
#     'vw': 309.771648})
# Bar({   'c': 311.2,
#     'h': 311.7,
#     'l': 310.06,
#     'n': 243,
#     'o': 311.35,
#     't': '2020-01-28T09:00:00Z',
#     'v': 18709,
#     'vw': 310.941153})
# Bar({   'c': 311.5,
#     'h': 311.71,
#     'l': 311.45,
#     'n': 89,
#     'o': 311.58,
#     't': '2020-01-28T10:00:00Z',
#     'v': 7515,
#     'vw': 311.549653})
# Bar({   'c': 311.89,
#     'h': 311.89,
#     'l': 310.55,
#     'n': 165,
#     'o': 311.31,
#     't': '2020-01-28T11:00:00Z',
#     'v': 13938,
#     'vw': 311.188617})
# Bar({   'c': 312.27,
#     'h': 312.9,
#     'l': 311.22,
#     'n': 1796,
#     'o': 311.83,
#     't': '2020-01-28T12:00:00Z',
#     'v': 169951,
#     'vw': 312.260951})
# Bar({   'c': 312.4014,
#     'h': 312.95,
#     'l': 311.2,
#     'n': 3103,
#     'o': 311.9001,
#     't': '2020-01-28T13:00:00Z',
#     'v': 317065,
#     'vw': 312.187454})
# Bar({   'c': 312.97,
#     'h': 314.03,
#     'l': 312.19,
#     'n': 47078,
#     'o': 312.5,
#     't': '2020-01-28T14:00:00Z',
#     'v': 4987739,
#     'vw': 313.096355})
# Bar({   'c': 315.815,
#     'h': 315.84,
#     'l': 312.42,
#     'n': 53017,
#     'o': 313,
#     't': '2020-01-28T15:00:00Z',
#     'v': 5953689,
#     'vw': 314.036279})
# Bar({   'c': 316.53,
#     'h': 316.77,
#     'l': 315,
#     'n': 38376,
#     'o': 315.8163,
#     't': '2020-01-28T16:00:00Z',
#     'v': 4067428,
#     'vw': 315.81594})
# Bar({   'c': 316.7,
#     'h': 317.17,
#     'l': 316.01,
#     'n': 28488,
#     'o': 316.5324,
#     't': '2020-01-28T17:00:00Z',
#     'v': 3001934,
#     'vw': 316.652804})
# Bar({   'c': 316.84,
#     'h': 316.94,
#     'l': 316.11,
#     'n': 22075,
#     'o': 316.71,
#     't': '2020-01-28T18:00:00Z',
#     'v': 2321272,
#     'vw': 316.488846})
# Bar({   'c': 318.35,
#     'h': 318.37,
#     'l': 316.81,
#     'n': 33298,
#     'o': 316.84,
#     't': '2020-01-28T19:00:00Z',
#     'v': 3367676,
#     'vw': 317.470767})
# Bar({   'c': 317.76,
#     'h': 318.4,
#     'l': 316.67,
#     'n': 62494,
#     'o': 318.3201,
#     't': '2020-01-28T20:00:00Z',
#     'v': 6741888,
#     'vw': 317.701596})
# Bar({   'c': 321.6,
#     'h': 327.9,
#     'l': 317.46,
#     'n': 44921,
#     'o': 317.69,
#     't': '2020-01-28T21:00:00Z',
#     'v': 7108639,
#     'vw': 321.532216})
# Bar({   'c': 322.32,
#     'h': 324.81,
#     'l': 317.69,
#     'n': 13772,
#     'o': 321.67,
#     't': '2020-01-28T22:00:00Z',
#     'v': 2022667,
#     'vw': 321.22121})
# Bar({   'c': 321.8,
#     'h': 322.88,
#     'l': 321.07,
#     'n': 2946,
#     'o': 322.32,
#     't': '2020-01-28T23:00:00Z',
#     'v': 306401,
#     'vw': 321.730617})
# Bar({   'c': 322.5,
#     'h': 322.59,
#     'l': 321.6,
#     'n': 1552,
#     'o': 321.8,
#     't': '2020-01-29T00:00:00Z',
#     'v': 146399,
#     'vw': 322.043188})
# Bar({   'c': 324.43,
#     'h': 324.65,
#     'l': 323.2,
#     'n': 463,
#     'o': 324.25,
#     't': '2020-01-29T09:00:00Z',
#     'v': 39552,
#     'vw': 324.003761})
# Bar({   'c': 324.59,
#     'h': 324.6,
#     'l': 323.75,
#     'n': 200,
#     'o': 324.32,
#     't': '2020-01-29T10:00:00Z',
#     'v': 21342,
#     'vw': 324.29388})
# Bar({   'c': 323.85,
#     'h': 325.07,
#     'l': 323.68,
#     'n': 581,
#     'o': 324.55,
#     't': '2020-01-29T11:00:00Z',
#     'v': 53659,
#     'vw': 324.262246})
# Bar({   'c': 323.1,
#     'h': 324.41,
#     'l': 322.59,
#     'n': 2608,
#     'o': 323.85,
#     't': '2020-01-29T12:00:00Z',
#     'v': 244456,
#     'vw': 323.301443})
# Bar({   'c': 323.33,
#     'h': 324.85,
#     'l': 322.6,
#     'n': 5559,
#     'o': 323.9,
#     't': '2020-01-29T13:00:00Z',
#     'v': 607476,
#     'vw': 323.884427})
# Bar({   'c': 323.36,
#     'h': 327.25,
#     'l': 322.66,
#     'n': 109429,
#     'o': 323.31,
#     't': '2020-01-29T14:00:00Z',
#     'v': 12166485,
#     'vw': 324.848324})
# Bar({   'c': 325.39,
#     'h': 325.5,
#     'l': 321.38,
#     'n': 90332,
#     'o': 323.34,
#     't': '2020-01-29T15:00:00Z',
#     'v': 10426275,
#     'vw': 323.851648})
# Bar({   'c': 327.15,
#     'h': 327.8,
#     'l': 325.24,
#     'n': 65209,
#     'o': 325.38,
#     't': '2020-01-29T16:00:00Z',
#     'v': 8283284,
#     'vw': 326.645015})
# Bar({   'c': 326.34,
#     'h': 327.63,
#     'l': 326.12,
#     'n': 39859,
#     'o': 327.1667,
#     't': '2020-01-29T17:00:00Z',
#     'v': 4300908,
#     'vw': 326.865488})
# Bar({   'c': 326.67,
#     'h': 326.92,
#     'l': 325.46,
#     'n': 29803,
#     'o': 326.34,
#     't': '2020-01-29T18:00:00Z',
#     'v': 2947348,
#     'vw': 326.313345})
# Bar({   'c': 327.03,
#     'h': 327.85,
#     'l': 324.0005,
#     'n': 42468,
#     'o': 326.67,
#     't': '2020-01-29T19:00:00Z',
#     'v': 4521448,
#     'vw': 327.088168})
# Bar({   'c': 324.36,
#     'h': 327.55,
#     'l': 321.7,
#     'n': 72327,
#     'o': 327.045,
#     't': '2020-01-29T20:00:00Z',
#     'v': 7461308,
#     'vw': 325.946648})
# Bar({   'c': 324,
#     'h': 324.86,
#     'l': 322.7295,
#     'n': 2932,
#     'o': 324.32,
#     't': '2020-01-29T21:00:00Z',
#     'v': 2728603,
# ...
# Bar({   'c': 144.1,
#     'h': 144.66,
#     'l': 142.11,
#     'n': 8734,
#     'o': 142.1125,
#     't': '2022-10-14T12:00:00Z',
#     'v': 649510,
#     'vw': 143.355859})
# Bar({   'c': 142.11,
#     'h': 144.52,
#     'l': 141.39,
#     'n': 125084,
#     'o': 144.12,
#     't': '2022-10-14T13:00:00Z',
#     'v': 13866163,
#     'vw': 142.814959})
# Bar({   'c': 140.3158,
#     'h': 142.13,
#     'l': 139.51,
#     'n': 138650,
#     'o': 142.12,
#     't': '2022-10-14T14:00:00Z',
#     'v': 15687323,
#     'vw': 140.561686})
# Bar({   'c': 139.64,
#     'h': 140.94,
#     'l': 139.24,
#     'n': 82233,
#     'o': 140.34,
#     't': '2022-10-14T15:00:00Z',
#     'v': 9368834,
#     'vw': 140.062606})
# Bar({   'c': 139.13,
#     'h': 140.21,
#     'l': 138.98,
#     'n': 63567,
#     'o': 139.64,
#     't': '2022-10-14T16:00:00Z',
#     'v': 6452787,
#     'vw': 139.470394})
# Bar({   'c': 139.5,
#     'h': 139.64,
#     'l': 138.95,
#     'n': 53342,
#     'o': 139.14,
#     't': '2022-10-14T17:00:00Z',
#     'v': 5721864,
#     'vw': 139.312574})
# Bar({   'c': 138.805,
#     'h': 139.51,
#     'l': 138.39,
#     'n': 66397,
#     'o': 139.5,
#     't': '2022-10-14T18:00:00Z',
#     'v': 7836638,
#     'vw': 138.767567})
# Bar({   'c': 138.38,
#     'h': 139.18,
#     'l': 138.19,
#     'n': 133976,
#     'o': 138.81,
#     't': '2022-10-14T19:00:00Z',
#     'v': 17049027,
#     'vw': 138.653618})
# Bar({   'c': 138.41,
#     'h': 139.01,
#     'l': 138.2,
#     'n': 4683,
#     'o': 138.38,
#     't': '2022-10-14T20:00:00Z',
#     'v': 11338961,
#     'vw': 138.382646})
# Bar({   'c': 138.36,
#     'h': 138.48,
#     'l': 138.25,
#     'n': 1661,
#     'o': 138.42,
#     't': '2022-10-14T21:00:00Z',
#     'v': 72910,
#     'vw': 138.343728})
# Bar({   'c': 138.07,
#     'h': 138.36,
#     'l': 138.04,
#     'n': 1992,
#     'o': 138.36,
#     't': '2022-10-14T22:00:00Z',
#     'v': 55279,
#     'vw': 138.181565})
# Bar({   'c': 138.08,
#     'h': 138.1,
#     'l': 138,
#     'n': 1029,
#     'o': 138.07,
#     't': '2022-10-14T23:00:00Z',
#     'v': 48358,
#     'vw': 138.055648})
# Bar({   'c': 139.07,
#     'h': 139.07,
#     'l': 139.07,
#     'n': 3,
#     'o': 139.07,
#     't': '2022-10-17T05:00:00Z',
#     'v': 146,
#     'vw': 139.071712})
# Bar({   'c': 139.9,
#     'h': 142.99,
#     'l': 139.58,
#     'n': 946,
#     'o': 142.99,
#     't': '2022-10-17T08:00:00Z',
#     'v': 52012,
#     'vw': 139.901097})
# Bar({   'c': 139.94,
#     'h': 140.1,
#     'l': 139.76,
#     'n': 545,
#     'o': 139.81,
#     't': '2022-10-17T09:00:00Z',
#     'v': 28220,
#     'vw': 139.950758})
# Bar({   'c': 140.33,
#     'h': 140.44,
#     'l': 139.85,
#     'n': 904,
#     'o': 139.98,
#     't': '2022-10-17T10:00:00Z',
#     'v': 69397,
#     'vw': 140.119022})
# Bar({   'c': 140.37,
#     'h': 140.44,
#     'l': 139.89,
#     'n': 3438,
#     'o': 140.31,
#     't': '2022-10-17T11:00:00Z',
#     'v': 256306,
#     'vw': 140.168143})
# Bar({   'c': 141.0497,
#     'h': 141.2,
#     'l': 140.21,
#     'n': 6728,
#     'o': 140.38,
#     't': '2022-10-17T12:00:00Z',
#     'v': 468428,
#     'vw': 140.778494})
# Bar({   'c': 142,
#     'h': 142.69,
#     'l': 140.49,
#     'n': 149211,
#     'o': 141.05,
#     't': '2022-10-17T13:00:00Z',
#     'v': 14906954,
#     'vw': 141.849908})
# Bar({   'c': 140.9772,
#     'h': 142.22,
#     'l': 140.71,
#     'n': 112589,
#     'o': 142.005,
#     't': '2022-10-17T14:00:00Z',
#     'v': 14319761,
#     'vw': 141.6758})
# Bar({   'c': 141.68,
#     'h': 141.89,
#     'l': 140.27,
#     'n': 83086,
#     'o': 140.975,
#     't': '2022-10-17T15:00:00Z',
#     'v': 10602699,
#     'vw': 141.046366})
# Bar({   'c': 141.8293,
#     'h': 141.93,
#     'l': 141.19,
#     'n': 54924,
#     'o': 141.68,
#     't': '2022-10-17T16:00:00Z',
#     'v': 6376894,
#     'vw': 141.644623})
# Bar({   'c': 142.3578,
#     'h': 142.59,
#     'l': 141.67,
#     'n': 59496,
#     'o': 141.83,
#     't': '2022-10-17T17:00:00Z',
#     'v': 7569549,
#     'vw': 142.233633})
# Bar({   'c': 142.68,
#     'h': 142.83,
#     'l': 142.1659,
#     'n': 58120,
#     'o': 142.37,
#     't': '2022-10-17T18:00:00Z',
#     'v': 6946716,
#     'vw': 142.523389})
# Bar({   'c': 142.405,
#     'h': 142.9,
#     'l': 142.11,
#     'n': 95385,
#     'o': 142.67,
#     't': '2022-10-17T19:00:00Z',
#     'v': 11658623,
#     'vw': 142.527075})
# Bar({   'c': 142.5,
#     'h': 142.62,
#     'l': 142.1,
#     'n': 3398,
#     'o': 142.4,
#     't': '2022-10-17T20:00:00Z',
#     'v': 11704346,
#     'vw': 142.407544})
# Bar({   'c': 142.68,
#     'h': 142.72,
#     'l': 142.43,
#     'n': 1301,
#     'o': 142.46,
#     't': '2022-10-17T21:00:00Z',
#     'v': 67873,
#     'vw': 142.573631})
# Bar({   'c': 143.07,
#     'h': 143.1,
#     'l': 142.66,
#     'n': 1795,
#     'o': 142.67,
#     't': '2022-10-17T22:00:00Z',
#     'v': 122161,
#     'vw': 142.938246})
# Bar({   'c': 143.45,
#     'h': 143.5,
#     'l': 143.02,
#     'n': 1417,
#     'o': 143.08,
#     't': '2022-10-17T23:00:00Z',
#     'v': 88228,
#     'vw': 143.338869})
# Bar({   'c': 144.81,
#     'h': 144.9,
#     'l': 144.32,
#     'n': 13,
#     'o': 144.32,
#     't': '2022-10-18T04:00:00Z',
#     'v': 556,
#     'vw': 144.694712})
# Bar({   'c': 145.66,
#     'h': 145.66,
#     'l': 145.66,
#     'n': 4,
#     'o': 145.66,
#     't': '2022-10-18T05:00:00Z',
#     'v': 216,
#     'vw': 145.607963})
# Bar({   'c': 144.8,
#     'h': 144.8,
#     'l': 144.8,
#     'n': 4,
#     'o': 144.8,
#     't': '2022-10-18T06:00:00Z',
#     'v': 624,
#     'vw': 144.800032})
# Bar({   'c': 144.23,
#     'h': 145.25,
#     'l': 144.02,
#     'n': 1802,
#     'o': 144.21,
#     't': '2022-10-18T08:00:00Z',
#     'v': 93387,
#     'vw': 144.783363})
# Bar({   'c': 144.38,
#     'h': 144.38,
#     'l': 143.66,
#     'n': 983,
#     'o': 144.21,
#     't': '2022-10-18T09:00:00Z',
#     'v': 57866,
#     'vw': 144.013364})
# Bar({   'c': 144.23,
#     'h': 144.82,
#     'l': 144.1615,
#     'n': 944,
#     'o': 144.36,
#     't': '2022-10-18T10:00:00Z',
#     'v': 52833,
#     'vw': 144.460127})
# Bar({   'c': 144.74,
#     'h': 145.01,
#     'l': 144.16,
#     'n': 5516,
#     'o': 144.23,
#     't': '2022-10-18T11:00:00Z',
#     'v': 330744,
#     'vw': 144.707179})
# Bar({   'c': 145.4,
#     'h': 145.43,
#     'l': 142.054,
#     'n': 6596,
#     'o': 144.74,
#     't': '2022-10-18T12:00:00Z',
#     'v': 417588,
#     'vw': 145.112165})
# Bar({   'c': 145.56,
#     'h': 146.7,
#     'l': 145.01,
#     'n': 121218,
#     'o': 145.39,
#     't': '2022-10-18T13:00:00Z',
#     'v': 12682360,
#     'vw': 146.025065})
# Bar({   'c': 145.085,
#     'h': 145.96,
#     'l': 144.83,
#     'n': 94334,
#     'o': 145.56,
#     't': '2022-10-18T14:00:00Z',
#     'v': 10676695,
#     'vw': 145.455708})
# Bar({   'c': 144.015,
#     'h': 145.18,
#     'l': 142.965,
#     'n': 92106,
#     'o': 145.085,
#     't': '2022-10-18T15:00:00Z',
#     'v': 10909725,
#     'vw': 143.940158})
# Bar({   'c': 144.73,
#     'h': 145.3,
#     'l': 143.6,
#     'n': 68510,
#     'o': 144.005,
#     't': '2022-10-18T16:00:00Z',
#     'v': 8592336,
#     'vw': 144.595786})
# Bar({   'c': 145.33,
#     'h': 145.63,
#     'l': 144.14,
#     'n': 63635,
#     'o': 144.73,
#     't': '2022-10-18T17:00:00Z',
#     'v': 7620587,
#     'vw': 144.925646})
# Bar({   'c': 142.5,
#     'h': 145.41,
#     'l': 140.61,
#     'n': 173826,
#     'o': 145.33,
#     't': '2022-10-18T18:00:00Z',
#     'v': 22216517,
#     'vw': 142.894918})
# Bar({   'c': 143.79,
#     'h': 143.89,
#     'l': 141.54,
#     'n': 144212,
#     'o': 142.481,
#     't': '2022-10-18T19:00:00Z',
#     'v': 18215859,
#     'vw': 142.803969})
# Bar({   'c': 144.3671,
#     'h': 144.82,
#     'l': 143.5,
#     'n': 6298,
#     'o': 143.79,
#     't': '2022-10-18T20:00:00Z',
#     'v': 6945710,
#     'vw': 143.812573})
# Bar({   'c': 144.6699,
#     'h': 144.78,
#     'l': 144.32,
#     'n': 1624,
#     'o': 144.33,
#     't': '2022-10-18T21:00:00Z',
#     'v': 123590,
#     'vw': 144.550599})
# Bar({   'c': 144.48,
#     'h': 144.64,
#     'l': 144.33,
#     'n': 1001,
#     'o': 144.52,
#     't': '2022-10-18T22:00:00Z',
#     'v': 68294,
#     'vw': 144.446226})
# Bar({   'c': 144.88,
#     'h': 145.5,
#     'l': 144.42,
#     'n': 1779,
#     'o': 144.48,
#     't': '2022-10-18T23:00:00Z',
#     'v': 125804,
#     'vw': 145.028774})
# Bar({   'c': 143.5,
#     'h': 143.5,
#     'l': 143.5,
#     'n': 14,
#     'o': 143.5,
#     't': '2022-10-19T07:00:00Z',
#     'v': 175,
#     'vw': 143.521943})
# Bar({   'c': 143.02,
#     'h': 144.15,
#     'l': 142.4,
#     'n': 1421,
#     'o': 144.06,
#     't': '2022-10-19T08:00:00Z',
#     'v': 83448,
#     'vw': 142.967478})
# Bar({   'c': 144.41,
#     'h': 144.5,
#     'l': 143,
#     'n': 1135,
#     'o': 143,
#     't': '2022-10-19T09:00:00Z',
#     'v': 98621,
#     'vw': 143.811557})
# Bar({   'c': 143.21,
#     'h': 144.38,
#     'l': 143.21,
#     'n': 1042,
#     'o': 144.29,
#     't': '2022-10-19T10:00:00Z',
#     'v': 75877,
#     'vw': 143.658192})
# Bar({   'c': 142.53,
#     'h': 143.63,
#     'l': 141.9104,
#     'n': 4988,
#     'o': 143.46,
#     't': '2022-10-19T11:00:00Z',
#     'v': 328184,
#     'vw': 142.477047})
# Bar({   'c': 141.82,
#     'h': 143.391,
#     'l': 141.5,
#     'n': 6667,
#     'o': 142.54,
#     't': '2022-10-19T12:00:00Z',
#     'v': 410649,
#     'vw': 141.856887})
# Bar({   'c': 143.43,
#     'h': 144.13,
#     'l': 141.38,
#     'n': 93075,
#     'o': 141.82,
#     't': '2022-10-19T13:00:00Z',
#     'v': 9581424,
#     'vw': 143.076443})
# Bar({   'c': 143.6,
#     'h': 144.9492,
#     'l': 143.17,
#     'n': 88719,
#     'o': 143.43,
#     't': '2022-10-19T14:00:00Z',
#     'v': 9856595,
#     'vw': 144.151808})
# Bar({   'c': 143.94,
#     'h': 144.34,
#     'l': 143.23,
#     'n': 61531,
#     'o': 143.59,
#     't': '2022-10-19T15:00:00Z',
#     'v': 7185229,
#     'vw': 143.751559})
# Bar({   'c': 143.06,
#     'h': 143.99,
#     'l': 142.85,
#     'n': 55124,
#     'o': 143.94,
#     't': '2022-10-19T16:00:00Z',
#     'v': 5861548,
#     'vw': 143.424967})
# Bar({   'c': 142.805,
#     'h': 143.2307,
#     'l': 142.17,
#     'n': 57976,
#     'o': 143.06,
#     't': '2022-10-19T17:00:00Z',
#     'v': 6403493,
#     'vw': 142.614951})
# Bar({   'c': 142.95,
#     'h': 143.59,
#     'l': 142.62,
#     'n': 51106,
#     'o': 142.8,
#     't': '2022-10-19T18:00:00Z',
#     'v': 6100633,
#     'vw': 143.172893})
# Bar({   'c': 143.9,
#     'h': 143.96,
#     'l': 142.83,
#     'n': 82067,
#     'o': 142.96,
#     't': '2022-10-19T19:00:00Z',
#     'v': 9977028,
#     'vw': 143.445743})
# Bar({   'c': 143.93,
#     'h': 144.59,
#     'l': 143.4,
#     'n': 2823,
#     'o': 143.9,
#     't': '2022-10-19T20:00:00Z',
#     'v': 5607000,
#     'vw': 143.86205})
# Bar({   'c': 143.76,
#     'h': 143.99,
#     'l': 143.75,
#     'n': 858,
#     'o': 143.8912,
#     't': '2022-10-19T21:00:00Z',
#     'v': 62201,
#     'vw': 143.863801})
# Bar({   'c': 143.3,
#     'h': 143.9,
#     'l': 143.3,
#     'n': 627,
#     'o': 143.78,
#     't': '2022-10-19T22:00:00Z',
#     'v': 44445,
#     'vw': 143.647866})
# Bar({   'c': 143,
#     'h': 143.3,
#     'l': 142.81,
#     'n': 1003,
#     'o': 143.25,
#     't': '2022-10-19T23:00:00Z',
#     'v': 69518,
#     'vw': 143.058029})
# Bar({   'c': 142.59,
#     'h': 142.59,
#     'l': 142.59,
#     'n': 2,
#     'o': 142.59,
#     't': '2022-10-20T04:00:00Z',
#     'v': 617,
#     'vw': 142.59})
# Bar({   'c': 142.74,
#     'h': 142.74,
#     'l': 142.74,
#     'n': 1,
#     'o': 142.74,
#     't': '2022-10-20T05:00:00Z',
#     'v': 100,
#     'vw': 142.74})
# Bar({   'c': 142.8,
#     'h': 142.81,
#     'l': 142.8,
#     'n': 5,
#     'o': 142.81,
#     't': '2022-10-20T06:00:00Z',
#     'v': 246,
#     'vw': 142.801504})
# Bar({   'c': 142.82,
#     'h': 142.9,
#     'l': 142.2,
#     'n': 451,
#     'o': 142.49,
#     't': '2022-10-20T08:00:00Z',
#     'v': 20650,
#     'vw': 142.594402})
# Bar({   'c': 143,
#     'h': 143.15,
#     'l': 142.83,
#     'n': 306,
#     'o': 142.85,
#     't': '2022-10-20T09:00:00Z',
#     'v': 16431,
#     'vw': 142.981489})
# Bar({   'c': 143.83,
#     'h': 144.11,
#     'l': 142.8,
#     'n': 647,
#     'o': 143,
#     't': '2022-10-20T10:00:00Z',
#     'v': 41640,
#     'vw': 143.493958})
# Bar({   'c': 143.71,
#     'h': 144.2,
#     'l': 143.41,
#     'n': 2527,
#     'o': 143.7403,
#     't': '2022-10-20T11:00:00Z',
#     'v': 168610,
#     'vw': 143.839815})
# Bar({   'c': 142.51,
#     'h': 144.48,
#     'l': 142.51,
#     'n': 6778,
#     'o': 143.7298,
#     't': '2022-10-20T12:00:00Z',
#     'v': 1798534,
#     'vw': 143.751532})
# Bar({   'c': 144.63,
#     'h': 145.3,
#     'l': 142.47,
#     'n': 91750,
#     'o': 142.5,
#     't': '2022-10-20T13:00:00Z',
#     'v': 9409546,
#     'vw': 144.237557})
# Bar({   'c': 145.69,
#     'h': 145.89,
#     'l': 144.57,
#     'n': 86443,
#     'o': 144.63,
#     't': '2022-10-20T14:00:00Z',
#     'v': 9547126,
#     'vw': 145.314356})
# Bar({   'c': 145.38,
#     'h': 145.83,
#     'l': 144.83,
#     'n': 61959,
#     'o': 145.7,
#     't': '2022-10-20T15:00:00Z',
#     'v': 6644691,
#     'vw': 145.44647})
# Bar({   'c': 144.63,
#     'h': 145.41,
#     'l': 144.24,
#     'n': 63142,
#     'o': 145.37,
#     't': '2022-10-20T16:00:00Z',
#     'v': 6628667,
#     'vw': 144.818253})
# Bar({   'c': 143.5699,
#     'h': 144.69,
#     'l': 143.33,
#     'n': 61759,
#     'o': 144.6299,
#     't': '2022-10-20T17:00:00Z',
#     'v': 7044800,
#     'vw': 144.013363})
# Bar({   'c': 143.305,
#     'h': 143.64,
#     'l': 142.65,
#     'n': 60609,
#     'o': 143.56,
#     't': '2022-10-20T18:00:00Z',
#     'v': 6595570,
#     'vw': 143.122296})
# Bar({   'c': 143.33,
#     'h': 143.78,
#     'l': 143,
#     'n': 74559,
#     'o': 143.3,
#     't': '2022-10-20T19:00:00Z',
#     'v': 9384493,
#     'vw': 143.396444})
# Bar({   'c': 143.35,
#     'h': 143.67,
#     'l': 143,
#     'n': 2433,
#     'o': 143.33,
#     't': '2022-10-20T20:00:00Z',
#     'v': 7017183,
#     'vw': 143.390453})
# Bar({   'c': 142.9777,
#     'h': 143.49,
#     'l': 142.83,
#     'n': 782,
#     'o': 143.4,
#     't': '2022-10-20T21:00:00Z',
#     'v': 55180,
#     'vw': 143.190338})
# Bar({   'c': 142.32,
#     'h': 142.87,
#     'l': 142.11,
#     'n': 1272,
#     'o': 142.85,
#     't': '2022-10-20T22:00:00Z',
#     'v': 64039,
#     'vw': 142.489092})
# Bar({   'c': 142.72,
#     'h': 142.72,
#     'l': 142.05,
#     'n': 933,
#     'o': 142.43,
#     't': '2022-10-20T23:00:00Z',
#     'v': 66107,
#     'vw': 142.287204})
# Bar({   'c': 142.15,
#     'h': 142.79,
#     'l': 142.03,
#     'n': 732,
#     'o': 142.79,
#     't': '2022-10-21T08:00:00Z',
#     'v': 47166,
#     'vw': 142.27354})
# Bar({   'c': 142.17,
#     'h': 142.29,
#     'l': 141.85,
#     'n': 622,
#     'o': 142.2,
#     't': '2022-10-21T09:00:00Z',
#     'v': 41887,
#     'vw': 142.071734})
# Bar({   'c': 142.03,
#     'h': 142.18,
#     'l': 142,
#     'n': 128,
#     'o': 142.03,
#     't': '2022-10-21T10:00:00Z',
#     'v': 13475,
#     'vw': 142.1469})
# Bar({   'c': 141.88,
#     'h': 142.7,
#     'l': 141.86,
#     'n': 2692,
#     'o': 142.24,
#     't': '2022-10-21T11:00:00Z',
#     'v': 162584,
#     'vw': 142.207922})
# Bar({   'c': 142.29,
#     'h': 143.39,
#     'l': 141.57,
#     'n': 5549,
#     'o': 141.93,
#     't': '2022-10-21T12:00:00Z',
#     'v': 338596,
#     'vw': 141.889542})
# Bar({   'c': 144.8898,
#     'h': 146.0562,
#     'l': 142.27,
#     'n': 100693,
#     'o': 142.27,
#     't': '2022-10-21T13:00:00Z',
#     'v': 15400445,
#     'vw': 143.382798})
# Bar({   'c': 144.1,
#     'h': 145.34,
#     'l': 144.0101,
#     'n': 104931,
#     'o': 144.8892,
#     't': '2022-10-21T14:00:00Z',
#     'v': 12581649,
#     'vw': 144.76345})
# Bar({   'c': 145.59,
#     'h': 145.6,
#     'l': 143.55,
#     'n': 81505,
#     'o': 144.1,
#     't': '2022-10-21T15:00:00Z',
#     'v': 10935282,
#     'vw': 144.504411})
# Bar({   'c': 145.775,
#     'h': 146.1,
#     'l': 145.02,
#     'n': 69959,
#     'o': 145.6,
#     't': '2022-10-21T16:00:00Z',
#     'v': 8232295,
#     'vw': 145.602003})
# Bar({   'c': 146.24,
#     'h': 146.285,
#     'l': 145.63,
#     'n': 54547,
#     'o': 145.78,
#     't': '2022-10-21T17:00:00Z',
#     'v': 6463784,
#     'vw': 145.995334})
# Bar({   'c': 146.65,
#     'h': 146.65,
#     'l': 145.94,
#     'n': 60517,
#     'o': 146.25,
#     't': '2022-10-21T18:00:00Z',
#     'v': 6778705,
#     'vw': 146.276561})
# Bar({   'c': 147.27,
#     'h': 147.8479,
#     'l': 146.6,
#     'n': 133242,
#     'o': 146.65,
#     't': '2022-10-21T19:00:00Z',
#     'v': 16866635,
#     'vw': 147.383634})
# Bar({   'c': 147.54,
#     'h': 147.6399,
#     'l': 147.27,
#     'n': 2821,
#     'o': 147.27,
#     't': '2022-10-21T20:00:00Z',
#     'v': 8015544,
#     'vw': 147.275966})
# Bar({   'c': 147.59,
#     'h': 147.67,
#     'l': 147.27,
#     'n': 944,
#     'o': 147.52,
#     't': '2022-10-21T21:00:00Z',
#     'v': 568656,
#     'vw': 147.301136})
# Bar({   'c': 147.57,
#     'h': 147.65,
#     'l': 147.56,
#     'n': 585,
#     'o': 147.63,
#     't': '2022-10-21T22:00:00Z',
#     'v': 42643,
#     'vw': 147.596631})
# Bar({   'c': 147.58,
#     'h': 147.75,
#     'l': 147.58,
#     'n': 769,
#     'o': 147.63,
#     't': '2022-10-21T23:00:00Z',
#     'v': 45210,
#     'vw': 147.678852})

# %%
apple_data = api.get_bars("AAPL", TimeFrame.Day,"2020-01-01","2022-10-21",adjustment='raw').df
print(apple_data.head())
# Out:
#                              open      high      low   close    volume  \
# timestamp
# 2020-01-02 05:00:00+00:00  296.27  300.6000  295.190  300.35  33912668
# 2020-01-03 05:00:00+00:00  296.95  300.5800  296.500  297.43  36633895
# 2020-01-06 05:00:00+00:00  293.70  299.9600  292.750  299.80  29644774
# 2020-01-07 05:00:00+00:00  299.98  300.9000  297.480  298.39  27877668
# 2020-01-08 05:00:00+00:00  297.17  304.4399  297.156  303.19  33090947
#
#                            trade_count        vwap
# timestamp
# 2020-01-02 05:00:00+00:00       283487  298.439523
# 2020-01-03 05:00:00+00:00       280941  298.810385
# 2020-01-06 05:00:00+00:00       242866  297.799601
# 2020-01-07 05:00:00+00:00       227869  298.924297
# 2020-01-08 05:00:00+00:00       261771  301.165488

# %%
apple_data.columns = apple_data.columns.to_flat_index()
apple_data.columns = [x[1] for x in apple_data.columns]
apple_data.reset_index(inplace=True)
print(apple_data.head())
# Out:
#                   timestamp       p         i        o       l         o  \
# 0 2020-01-02 05:00:00+00:00  296.27  300.6000  295.190  300.35  33912668
# 1 2020-01-03 05:00:00+00:00  296.95  300.5800  296.500  297.43  36633895
# 2 2020-01-06 05:00:00+00:00  293.70  299.9600  292.750  299.80  29644774
# 3 2020-01-07 05:00:00+00:00  299.98  300.9000  297.480  298.39  27877668
# 4 2020-01-08 05:00:00+00:00  297.17  304.4399  297.156  303.19  33090947
#
#         r           w
# 0  283487  298.439523
# 1  280941  298.810385
# 2  242866  297.799601
# 3  227869  298.924297
# 4  261771  301.165488

# %%
plot = apple_data.plot(x="timestamp",y="l",legend=False)
plot.set_xlabel("Date")
plot.set_ylabel("Apple Close Price($): ")
plt.show()

# %%
#calculating moving averages

apple_data['20_SMA'] = apple_data['l'].rolling(window=20, min_periods=1).mean()
apple_data['10_SMA'] = apple_data['l'].rolling(window=10, min_periods=1).mean()

# %%
#finding crossover points
apple_data["Cross"] = 0.0
apple_data["Cross"] = np.where(apple_data['10_SMA'] > apple_data['20_SMA'], 1.0,0.0)
apple_data['Signal'] = apple_data['Cross'].diff()

# %%
#map numbers to words
map_dict = {-1.0: "sell", 1.0: 'buy', 0.0: 'none'}
apple_data['Signal'] = apple_data['Signal'].map(map_dict)

# %%
#print(apple_data[apple_data['Signal'] != "none"].dropna())
apple_data.plot(x='timestamp',y=["l","20_SMA","10_SMA"],color=["k",'b','m'])
plt.plot(apple_data[apple_data['Signal']=='buy']['timestamp'],apple_data['20_SMA'][apple_data['Signal']=='buy'],"^",markersize=8,color='g',label='buy')

plt.plot(apple_data[apple_data['Signal']=='sell']['timestamp'],apple_data['20_SMA'][apple_data['Signal']=='sell'],'v',markersize=8,color='r',label='sell')

plt.xlabel("Date")
plt.ylabel("Apple Close Price ($)")
plt.legend()
plt.show()

# %%
api.get_bars("TSLA", TimeFrame.Hour, "2021-01-01","2022-10-24",adjustment='raw').df
# Out:
#                              open    high     low     close    volume  \
# timestamp
# 2021-01-04 09:00:00+00:00  709.00  726.75  709.00  726.7500    169981
# 2021-01-04 10:00:00+00:00  726.85  729.77  725.00  725.1200     66638
# 2021-01-04 11:00:00+00:00  725.60  728.00  725.00  726.1400     34710
# 2021-01-04 12:00:00+00:00  725.51  725.98  718.23  720.5000    520325
# 2021-01-04 13:00:00+00:00  726.00  726.00  718.20  719.6000    424894
# ...                           ...     ...     ...       ...       ...
# 2022-10-24 19:00:00+00:00  209.94  213.50  209.85  211.3000  14404959
# 2022-10-24 20:00:00+00:00  211.23  211.45  210.71  211.1500   2356136
# 2022-10-24 21:00:00+00:00  211.17  211.19  210.06  210.1803    121279
# 2022-10-24 22:00:00+00:00  210.30  210.74  210.22  210.4500     58122
# 2022-10-24 23:00:00+00:00  210.42  210.68  208.80  208.8000    135870
#
#                            trade_count        vwap
# timestamp
# 2021-01-04 09:00:00+00:00         6018  721.625499
# 2021-01-04 10:00:00+00:00         2380  726.723340
# 2021-01-04 11:00:00+00:00         1163  726.289263
# 2021-01-04 12:00:00+00:00        12700  721.778915
# 2021-01-04 13:00:00+00:00        11336  721.227980
# ...                                ...         ...
# 2022-10-24 19:00:00+00:00       141212  211.612177
# 2022-10-24 20:00:00+00:00         5293  211.233336
# 2022-10-24 21:00:00+00:00         2755  210.559231
# 2022-10-24 22:00:00+00:00         1469  210.522714
# 2022-10-24 23:00:00+00:00         2779  209.810740
#
# [7458 rows x 7 columns]

# %%
tesla_data = api.get_bars("TSLA", TimeFrame.Day,"2021-01-01","2022-10-24",adjustment='raw').df
print(tesla_data.head())
# Out:
#                              open      high       low   close    volume  \
# timestamp
# 2021-01-04 05:00:00+00:00  720.00  744.4899  717.1895  729.77  48671381
# 2021-01-05 05:00:00+00:00  723.92  740.8400  719.2000  735.11  32155175
# 2021-01-06 05:00:00+00:00  758.00  774.0000  749.1000  755.98  44703325
# 2021-01-07 05:00:00+00:00  778.25  816.9900  775.2000  816.04  51499085
# 2021-01-08 05:00:00+00:00  856.38  884.4900  838.3900  880.02  75056507
#
#                            trade_count        vwap
# timestamp
# 2021-01-04 05:00:00+00:00       952186  731.118129
# 2021-01-05 05:00:00+00:00       681717  734.044099
# 2021-01-06 05:00:00+00:00       962707  762.269623
# 2021-01-07 05:00:00+00:00      1164687  800.593709
# 2021-01-08 05:00:00+00:00      1799648  866.479508

# %%
tesla_data.columns = tesla_data.columns.to_flat_index()
tesla_data.columns = [x[1] for x in tesla_data.columns]
tesla_data.reset_index(inplace=True)
print(tesla_data.head())
# Out:
#                   timestamp       p         i         o       l         o  \
# 0 2021-01-04 05:00:00+00:00  720.00  744.4899  717.1895  729.77  48671381
# 1 2021-01-05 05:00:00+00:00  723.92  740.8400  719.2000  735.11  32155175
# 2 2021-01-06 05:00:00+00:00  758.00  774.0000  749.1000  755.98  44703325
# 3 2021-01-07 05:00:00+00:00  778.25  816.9900  775.2000  816.04  51499085
# 4 2021-01-08 05:00:00+00:00  856.38  884.4900  838.3900  880.02  75056507
#
#          r           w
# 0   952186  731.118129
# 1   681717  734.044099
# 2   962707  762.269623
# 3  1164687  800.593709
# 4  1799648  866.479508

# %%
plot = tesla_data.plot(x="timestamp",y="l",legend=False)
plot.set_xlabel("Date")
plot.set_ylabel("Tesla Close Price($): ")
plt.show()

# %%
#calculating moving averages

tesla_data['20_SMA'] = tesla_data['l'].rolling(window=20, min_periods=1).mean()
tesla_data['10_SMA'] = tesla_data['l'].rolling(window=10, min_periods=1).mean()

# %%
#finding crossover points
tesla_data["Cross"] = 0.0
tesla_data["Cross"] = np.where(tesla_data['10_SMA'] > tesla_data['20_SMA'], 1.0,0.0)
tesla_data['Signal'] = tesla_data['Cross'].diff()

# %%
#map numbers to words
map_dict = {-1.0: "sell", 1.0: 'buy', 0.0: 'none'}
tesla_data['Signal'] = tesla_data['Signal'].map(map_dict)

# %%
#print(apple_data[apple_data['Signal'] != "none"].dropna())
tesla_data.plot(x='timestamp',y=["l","20_SMA","10_SMA"],color=["k",'b','m'])
plt.plot(tesla_data[tesla_data['Signal']=='buy']['timestamp'],tesla_data['20_SMA'][tesla_data['Signal']=='buy'],"^",markersize=8,color='g',label='buy')

plt.plot(tesla_data[tesla_data['Signal']=='sell']['timestamp'],tesla_data['20_SMA'][tesla_data['Signal']=='sell'],'v',markersize=8,color='r',label='sell')

plt.xlabel("Date")
plt.ylabel("Tesla Close Price ($)")
plt.legend()
plt.show()

# %%
api.submit_order("AAPL",1,"buy","market",'day')
# Out:
# Order({   'asset_class': 'us_equity',
#     'asset_id': 'b0b6dd9d-8b9b-48a9-ba46-b9d54906e415',
#     'canceled_at': None,
#     'client_order_id': 'fa9578f1-e54c-4e94-8efa-3c7b536a9378',
#     'created_at': '2022-10-23T07:58:39.773907415Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': 'e53e9e9d-1106-4537-a4fd-c11656ac664e',
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': '',
#     'order_type': 'market',
#     'qty': '1',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'buy',
#     'source': None,
#     'status': 'accepted',
#     'stop_price': None,
#     'submitted_at': '2022-10-23T07:58:39.772463675Z',
#     'subtag': None,
#     'symbol': 'AAPL',
#     'time_in_force': 'day',
#     'trail_percent': None,
#     'trail_price': None,
#     'type': 'market',
#     'updated_at': '2022-10-23T07:58:39.773907415Z'})

# %%
api.submit_order("TSLA",1,"sell","market","day")
# Out:
# Order({   'asset_class': 'us_equity',
#     'asset_id': '8ccae427-5dd0-45b3-b5fe-7ba5e422c766',
#     'canceled_at': None,
#     'client_order_id': '84d39bfa-549b-41d2-aec6-8cbb3db19671',
#     'created_at': '2022-10-23T07:58:39.827398152Z',
#     'expired_at': None,
#     'extended_hours': False,
#     'failed_at': None,
#     'filled_at': None,
#     'filled_avg_price': None,
#     'filled_qty': '0',
#     'hwm': None,
#     'id': 'a748a55f-8e44-458f-89ab-ba6cd75e653f',
#     'legs': None,
#     'limit_price': None,
#     'notional': None,
#     'order_class': '',
#     'order_type': 'market',
#     'qty': '1',
#     'replaced_at': None,
#     'replaced_by': None,
#     'replaces': None,
#     'side': 'sell',
#     'source': None,
#     'status': 'accepted',
#     'stop_price': None,
#     'submitted_at': '2022-10-23T07:58:39.826217292Z',
#     'subtag': None,
#     'symbol': 'TSLA',
#     'time_in_force': 'day',
#     'trail_percent': None,
#     'trail_price': None,
#     'type': 'market',
#     'updated_at': '2022-10-23T07:58:39.827398152Z'})

# %%
portfolio = api.list_positions()

for position in portfolio:
    print("{} shares of {}".format(position.qty,position.symbol))

# %%
api.get_quotes("APPL",TimeFrame.Day,"2020-06-08","2021-06-08",limit=10).df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/hw/r_q5t6hd2r71fj7t3zwm74kc0000gn/T/ipykernel_90122/1400847216.py in <module>
# ----> 1 api.get_quotes("APPL",TimeFrame.Day,"2020-06-08","2021-06-08",limit=10).df
#
# TypeError: get_quotes() got multiple values for argument 'limit'

# %%
def process_quote(quote):
    print(quote)

# %%
quote_iter=api.get_quotes_iter("APPL","2021-06-08","2021-06-08",limit=10)
for quote in quote_iter:
    process_quote(quote)

# %%
api.get_trades("APPL","2021-06-08","2021-06-08",limit=10).df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
def process_trade(trade):
    print(trade)

# %%
trades_iter = api.get_trades_iter("APPL","2021-06-08","2021-06-08",limit=10)
for trade in trades_iter:
    process_trade(trade)

# %%
async def trade_callback(t):
    print('trade',t)
    
async def quote_callback(q):
    print("quote",q)
    
#class instance
stream = Stream(alpaca_api_key,alpaca_secret_key,base_url=URL("https://paper-api.alpaca.markets"), data_feed='iex')

stream.subscribe_trades(trade_callback,"APPL")
stream.subscribe_quotes(quote_callback,"IBM")

stream.run()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /var/folders/hw/r_q5t6hd2r71fj7t3zwm74kc0000gn/T/ipykernel_90122/2414960996.py in <module>
#      11 stream.subscribe_quotes(quote_callback,"IBM")
#      12
# ---> 13 stream.run()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/alpaca_trade_api/stream.py in run(self)
#    1003     def run(self):
#    1004         try:
# -> 1005             asyncio.run(self._run_forever())
#    1006         except KeyboardInterrupt:
#    1007             print('keyboard interrupt, bye')
#
# ~/opt/anaconda3/lib/python3.9/asyncio/runners.py in run(main, debug)
#      31     """
#      32     if events._get_running_loop() is not None:
# ---> 33         raise RuntimeError(
#      34             "asyncio.run() cannot be called from a running event loop")
#      35
#
# RuntimeError: asyncio.run() cannot be called from a running event loop
